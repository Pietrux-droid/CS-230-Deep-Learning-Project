# %%
#Imports and directory
import os
import pickle
import random
import math
import numpy as np
import pandas as pd
import matplotlib
import torch
import torch.nn as nn
import optuna
from matplotlib import pyplot as plt
from pandas import Period
os.chdir("/home/ec2-user/CS-230-Deep-Learning-Project")
#os.chdir(r"C:\Users\gotta\OneDrive\Documents\Bureau\X\4A\US\Stanford\Classes\CS 230\Project\CS-230-Deep-Learning-Project")
# Out:
# /opt/pytorch/lib/python3.12/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]

# %%
# Basic functions including device and seeding
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
print("USING DEVICE:", device)

def save_object_to_file(obj, filepath):
    with open(filepath, "wb") as f:
        pickle.dump(obj, f)

def read_object_from_file(filepath):
    with open(filepath, "rb") as f:
        return pickle.load(f)

def seed_everything(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
# Out:
# USING DEVICE: cuda:0

# %%
# --- Data preparation ---
DATA_CSV_FR = os.path.join("data", "FR_price", "FR_lmp_processed.csv")
DATA_CSV_LOAD = os.path.join("data", "FR_DAM_Load", "FR_load_processed.csv")
DATA_CSV_REN = os.path.join("data", "FR_REN", "FR_ren_processed.csv")
DATA_CSV_LOAD_RT=os.path.join("data", "FR_DAM_Load", "FR_rt_load_processed.csv")
DATA_CSV_REN_RT=os.path.join("data", "FR_REN", "FR_rt_ren_processed.csv")

# %%
df_FR = pd.read_csv(DATA_CSV_FR)
load_FR = pd.read_csv(DATA_CSV_LOAD)
ren_FR = pd.read_csv(DATA_CSV_REN)
all_data_DA = pd.merge(df_FR, load_FR, on=['Time', 'Timezone', 'Year', 'Month', 'Day', 'Hour'], how='inner')
all_data_DA = pd.merge(all_data_DA, ren_FR, on=['Time', 'Timezone', 'Year', 'Month', 'Day', 'Hour'], how='inner')
all_data_DA.rename(columns={'MW':'Load_DA','Wind Onshore':'Wind_DA','Solar':'Solar_DA'}, inplace=True)
load_FR_rt = pd.read_csv(DATA_CSV_LOAD_RT)
ren_FR_rt = pd.read_csv(DATA_CSV_REN_RT)
all_data_RT = pd.merge(df_FR, load_FR_rt, on=['Time', 'Timezone', 'Year', 'Month', 'Day', 'Hour'], how='inner')
all_data_RT = pd.merge(all_data_RT, ren_FR_rt, on=['Time', 'Timezone', 'Year', 'Month', 'Day', 'Hour'], how='inner')
all_data_RT.rename(columns={'MW':'Load_RT','Wind Onshore':'Wind_RT','Solar':'Solar_RT'}, inplace=True)

all_data=pd.merge(all_data_DA,all_data_RT,on=['Time', 'Timezone', 'Year', 'Month', 'Day', 'Hour','EUR/MWh'], how='inner')
all_data
# Out:
#                             Time  Year  Month  Day  Hour Timezone  EUR/MWh  \
# 0      2019-10-01 00:00:00+02:00  2019     10    1     0   +02:00    33.09
# 1      2019-10-01 01:00:00+02:00  2019     10    1     1   +02:00    27.72
# 2      2019-10-01 02:00:00+02:00  2019     10    1     2   +02:00    23.12
# 3      2019-10-01 03:00:00+02:00  2019     10    1     3   +02:00    16.46
# 4      2019-10-01 04:00:00+02:00  2019     10    1     4   +02:00    15.66
# ...                          ...   ...    ...  ...   ...      ...      ...
# 52142  2025-09-30 19:00:00+02:00  2025      9   30    19   +02:00   117.00
# 52143  2025-09-30 20:00:00+02:00  2025      9   30    20   +02:00   106.18
# 52144  2025-09-30 21:00:00+02:00  2025      9   30    21   +02:00    83.23
# 52145  2025-09-30 22:00:00+02:00  2025      9   30    22   +02:00    73.00
# 52146  2025-09-30 23:00:00+02:00  2025      9   30    23   +02:00    75.73
#
#        Load_DA  Wind_DA  Solar_DA   Load_RT  Wind_RT  Solar_RT
# 0      44450.0  4975.31      0.00  43062.00  6076.00      0.00
# 1      41300.0  5338.58      0.00  40483.00  6137.00      0.00
# 2      40050.0  5702.33      0.00  39207.00  6342.00      0.00
# 3      37750.0  5667.94      0.00  37004.00  6355.00      0.00
# 4      36600.0  5633.30      0.00  36399.00  6217.00      0.00
# ...        ...      ...       ...       ...      ...       ...
# 52142  49000.0  2435.69   2158.72  49421.41  1939.43    901.85
# 52143  50400.0  2929.19    315.89  50315.77  2445.66    244.45
# 52144  46700.0  3480.47      0.00  47039.08  3116.56      0.00
# 52145  44100.0  3879.11      0.00  45544.52  3422.12      0.00
# 52146  46200.0  3960.98      0.00  45652.29  3348.44      0.00
#
# [52147 rows x 13 columns]

# %%
#Convert hour, day, month into cyclic features
def add_cyclical_features(df):
    df['Date']=pd.to_datetime(df[['Year', 'Month', 'Day', 'Hour']])
    df["DayOfWeek"] = df['Date'].dt.dayofweek
    # Hour of day (0-23)
    df["sin_hour"] = np.sin(2 * np.pi * df["Hour"] / 24)
    df["cos_hour"] = np.cos(2 * np.pi * df["Hour"] / 24)

    # Day of week (0-6 or 1-7 depending on your data)
    df["sin_day"] = np.sin(2 * np.pi * df["DayOfWeek"] / 7)
    df["cos_day"] = np.cos(2 * np.pi * df["DayOfWeek"] / 7)

    # Month (1-12)
    df["sin_month"] = np.sin(2 * np.pi * df["Month"] / 12)
    df["cos_month"] = np.cos(2 * np.pi * df["Month"] / 12)
    return df
all_data = add_cyclical_features(all_data)

# %%
import numpy as np
import pandas as pd

def create_sliding_window_numpy(
        df,
        target_col="EUR/MWh",
        window_days=7,
        forecast_horizon=1,
        rt_cols=["EUR/MWh", "Load_DA", "Solar_DA", "Wind_DA"],
        rt_cyc_cols=["sin_hour", "cos_hour", "sin_day", "cos_day", "sin_month", "cos_month"],
    ):

    df = df.sort_values("Date").reset_index(drop=True)
    hours = 24
    window_size = window_days * hours
    n = len(df)

    # ---- Storage ----
    X_rt_list = []
    X_rt_cyc_list = []
    y_list = []
    y1_list = []
    y7_list = []
    dates = []

    for i in range(window_size, n - forecast_horizon):

        dates.append(df.loc[i, "Date"])

        # =========================================
        # 1️⃣  REAL-TIME WINDOW   (unchanged)
        # =========================================
        rt_stack = [df.loc[i-window_size:i-1, col].values.astype(float)
                    for col in rt_cols]
        X_rt_list.append(np.stack(rt_stack, axis=1))

        rt_cyc_stack = [df.loc[i-window_size:i-1, col].values.astype(float)
                        for col in rt_cyc_cols]
        X_rt_cyc_list.append(np.stack(rt_cyc_stack, axis=1))



        # =========================================
        # 3️⃣  TARGETS (H-hour vector)
        # =========================================
        y_list.append(
            df.loc[i:i+forecast_horizon-1, target_col].values.astype(float)
        )

        y1_list.append(
            df.loc[i-hours:i-hours+forecast_horizon-1, target_col].values.astype(float)
        )

        y7_list.append(
            df.loc[i-7*hours:i-7*hours+forecast_horizon-1, target_col].values.astype(float)
        )

    # ----------- Convert to numpy arrays --------------
    X_rt       = np.array(X_rt_list)       # (N, window, n_rt)
    X_rt_cyc   = np.array(X_rt_cyc_list)   # (N, window, n_rt_cyc)

    y          = np.array(y_list)          # (N, H)
    y_1d       = np.array(y1_list)         # (N, H)
    y_7d       = np.array(y7_list)         # (N, H)
    dates      = np.array(dates)

    # ---- Merge RT windows ----
    X_rt_full = np.concatenate([X_rt, X_rt_cyc], axis=2)  # (N, window, n_rt+n_rt_cyc)



    # =====================================
    # FEATURE MAP (for normalization)
    # =====================================
    feature_map = {
        "rt_cols": rt_cols,
        "rt_cyc_cols": rt_cyc_cols,
        "rt_window_features": {
            "start_idx": 0,
            "end_idx": len(rt_cols)-1
        },
        "rt_cyclic_features": {
            "start_idx": len(rt_cols),
            "end_idx": len(rt_cols)+len(rt_cyc_cols)-1
        },

        "forecast_horizon": forecast_horizon
    }

    return X_rt_full, y, y_1d, y_7d, dates, feature_map

# %%
X_rt, y, y_1d, y_7d, dates, feature_map = create_sliding_window_numpy(all_data,
                                                                            target_col="EUR/MWh",
                                                                            window_days=7,
                                                                            forecast_horizon=1)

# %%
print("Shapes")
print("X_rt:", X_rt.shape)
print("y:", y.shape)
print("y_1d:", y_1d.shape)
print("y_7d:", y_7d.shape)
# Out:
# Shapes
# X_rt: (51978, 168, 10)
# y: (51978, 1)
# y_1d: (51978, 1)
# y_7d: (51978, 1)

# %%
def month_based_split_np(
        X_rt,
        y,
        y_1d,
        y_7d,
        dates,
        features_map,
        train_ratio=0.6,
        dev_ratio=0.2,
        seed=42
    ):
    """
    Month-based split for NumPy-array datasets.
    """

    # --- Convert dates to pandas for easy month extraction ---
    dates_pd = pd.to_datetime(dates)
    yearmonth = dates_pd.to_period("M")

    # --- Unique months ---
    all_months = np.array(yearmonth.unique())
    n_months = len(all_months)

    # --- Shuffle months ---
    rng = np.random.default_rng(seed)
    shuffled = rng.permutation(all_months)

    # --- Split ---
    n_train = int(train_ratio * n_months)
    n_dev   = int(dev_ratio * n_months)

    train_m = shuffled[:n_train]
    dev_m   = shuffled[n_train : n_train+n_dev]
    test_m  = shuffled[n_train+n_dev :]

    # --- Boolean masks on rows ---
    mask_train = yearmonth.isin(train_m)
    mask_dev   = yearmonth.isin(dev_m)
    mask_test  = yearmonth.isin(test_m)

    # --- Helper to index all arrays ---
    def select(mask):
        return (
            X_rt[mask],
            y[mask],
            y_1d[mask],
            y_7d[mask],
            dates[mask]
        )

    Xrt_tr, y_tr, y1d_tr, y7d_tr, d_tr = select(mask_train)
    Xrt_de, y_de, y1d_de, y7d_de, d_de = select(mask_dev)
    Xrt_te, y_te, y1d_te, y7d_te, d_te = select(mask_test)

    return {
        "train": (Xrt_tr, y_tr, y1d_tr, y7d_tr, d_tr),
        "dev":   (Xrt_de, y_de, y1d_de, y7d_de, d_de),
        "test":  (Xrt_te, y_te, y1d_te, y7d_te, d_te),
        "months": {
            "train": train_m,
            "dev": dev_m,
            "test": test_m
        },
        "feature_map": features_map
    }

# %%
splits = month_based_split_np(
    X_rt, y, y_1d, y_7d, dates, feature_map
)
Xrt_train, y_train, y1d_train, y7d_train, dates_train = splits["train"]
Xrt_dev,   y_dev,   y1d_dev,   y7d_dev,   dates_dev   = splits["dev"]
Xrt_test,  y_test,  y1d_test,  y7d_test,  dates_test  = splits["test"]

features_map = splits["feature_map"]

# %%
df_price  = all_data[["Time","EUR/MWh"]]

df_rt_load = all_data[["Time","Load_DA"]]
df_rt_ren  = all_data[["Time","Solar_DA","Wind_DA"]]
for df in [df_price, df_rt_load, df_rt_ren]:
    df["Date"] = pd.to_datetime(df["Time"], utc=True)
    df["YearMonth"] = df["Date"].dt.to_period("M")
train_months = splits["months"]["train"]  # <-- from your earlier split

df_price_tr  = df_price[df_price["YearMonth"].isin(train_months)]
df_rt_load_tr = df_rt_load[df_rt_load["YearMonth"].isin(train_months)]
df_rt_ren_tr  = df_rt_ren[df_rt_ren["YearMonth"].isin(train_months)]

stats_dict = {}

def compute_stats(df, cols, container, prefix=""):
    for c in cols:
        arr = df[c].astype(float).values
        container[prefix + c] = {
            "mean": float(np.nanmean(arr)),
            "std":  float(np.nanstd(arr) + 1e-8)
        }

# --- price y ---
compute_stats(df_price_tr, ["EUR/MWh"], stats_dict, prefix="price_")

# --- RT features ---
rt_cols = ["Load_DA", "Solar_DA", "Wind_DA"]
compute_stats(df_rt_load_tr.merge(df_rt_ren_tr, on="Date"), rt_cols, stats_dict, prefix="rt_")
# Out:
# /tmp/ipykernel_4678/606519030.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Date"] = pd.to_datetime(df["Time"], utc=True)
# /tmp/ipykernel_4678/606519030.py:7: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df["YearMonth"] = df["Date"].dt.to_period("M")
# /tmp/ipykernel_4678/606519030.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["YearMonth"] = df["Date"].dt.to_period("M")
# /tmp/ipykernel_4678/606519030.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Date"] = pd.to_datetime(df["Time"], utc=True)
# /tmp/ipykernel_4678/606519030.py:7: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df["YearMonth"] = df["Date"].dt.to_period("M")
# /tmp/ipykernel_4678/606519030.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["YearMonth"] = df["Date"].dt.to_period("M")
# /tmp/ipykernel_4678/606519030.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Date"] = pd.to_datetime(df["Time"], utc=True)
# /tmp/ipykernel_4678/606519030.py:7: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df["YearMonth"] = df["Date"].dt.to_period("M")
# /tmp/ipykernel_4678/606519030.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["YearMonth"] = df["Date"].dt.to_period("M")

# %%
def normalize_sets(
    Xrt, y,
    stats_dict,
    feature_map
):
    """
    Normalizes:
      - y using price stats
      - Xrt windowed features (EUR/MWh, Load_RT, Solar_RT, Wind_RT)
      - Xrt cyclic features untouched
      - Xda DA features
      - Xda cyclic features untouched
    """

    # --- Copies ---
    Xrt = Xrt.copy()
    y   = y.copy()

    # -----------------------
    # Normalize y
    # -----------------------
    y_mean = stats_dict["price_EUR/MWh"]["mean"]
    y_std  = stats_dict["price_EUR/MWh"]["std"]
    y = (y - y_mean) / y_std

    # -----------------------
    # Normalize Xrt
    # -----------------------
    rt_cols = feature_map["rt_cols"]
    rt_cyc_cols = feature_map["rt_cyc_cols"]
    start_rt = feature_map["rt_window_features"]["start_idx"]
    end_rt   = feature_map["rt_window_features"]["end_idx"]

    # Windowed RT features (first 4 columns)
    for j, feat in enumerate(rt_cols):
        if feat == "EUR/MWh":
            mean, std = y_mean, y_std
        else:
            mean = stats_dict[f"rt_{feat}"]["mean"]
            std  = stats_dict[f"rt_{feat}"]["std"]

        Xrt[:, :, start_rt + j] = (Xrt[:, :, start_rt + j] - mean) / std

    # Cyclic RT: do nothing

    # Cyclic DA: untouched

    return Xrt, y

# %%
Xrt_train_norm, y_train_norm = normalize_sets(
    Xrt_train, y_train,
    stats_dict,
    feature_map
)

Xrt_dev_norm, y_dev_norm = normalize_sets(
    Xrt_dev, y_dev,
    stats_dict,
    feature_map
)

Xrt_test_norm, y_test_norm = normalize_sets(
    Xrt_test, y_test,
    stats_dict,
    feature_map
)

# #Keep prices only (First channel)
# Xrt_train_norm = Xrt_train_norm[:, :, 0:1]
# Xrt_dev_norm = Xrt_dev_norm[:, :, 0:1]
# Xrt_test_norm = Xrt_test_norm[:, :, 0:1]

# Keep other features only
# Xrt_train_norm = Xrt_train_norm[:, :, 1:]
# Xrt_dev_norm = Xrt_dev_norm[:, :, 1:]
# Xrt_test_norm = Xrt_test_norm[:, :, 1:]

# %%
print("Shapes after normalization:")
print("Xrt_train_norm:", Xrt_train_norm.shape)
print("y_train_norm:", y_train_norm.shape)
# Out:
# Shapes after normalization:
# Xrt_train_norm: (31023, 168, 10)
# y_train_norm: (31023, 1)

# %%
class SimpleRNN(nn.Module):
    def __init__(self, 
                 n_features,
                 seq_len,
                 hidden_size=128,
                 num_layers=2,
                 dropout=0.2,
                 output_dim=1,
                 leaky_alpha=0.1,
                 use_batchnorm=True,
                 cnn_channels=32):

        super().__init__()

        self.seq_len = seq_len
        self.n_features = n_features
        self.use_batchnorm = use_batchnorm

        # ---------------------------------------------------
        #  CNN BLOCKS
        # ---------------------------------------------------
        self.cnn_block1 = nn.Sequential(
            nn.Conv1d(n_features, cnn_channels, kernel_size=5, padding=2),
            nn.MaxPool1d(2)
        )

        self.cnn_block2 = nn.Sequential(
            nn.Conv1d(cnn_channels, cnn_channels, kernel_size=3, padding=1),
            nn.MaxPool1d(2)
        )

        # Dropout ONLY after CNN
        self.dropout_cnn = nn.Dropout(dropout) if dropout > 0 else nn.Identity()

        # ---------------------------------------------------
        #  LSTM
        # ---------------------------------------------------
        self.lstm = nn.LSTM(
            input_size=cnn_channels,
            hidden_size=hidden_size,
            num_layers=num_layers,
            batch_first=True,
            dropout=dropout if num_layers > 1 else 0.0   # internal LSTM dropout between layers only
        )

        # No dropout after LSTM
        # self.dropout_lstm = ...

        if use_batchnorm:
            self.bn_lstm = nn.BatchNorm1d(hidden_size)

        # ---------------------------------------------------
        #  MLP HEAD
        # ---------------------------------------------------
        self.fc1 = nn.Linear(hidden_size, hidden_size)
        if use_batchnorm:
            self.bn_fc1 = nn.BatchNorm1d(hidden_size)

        self.act = nn.LeakyReLU(leaky_alpha)
        self.fc2 = nn.Linear(hidden_size, output_dim)


    def forward(self, x):

        # CNN
        x = x.transpose(1, 2)
        x = self.cnn_block1(x)
        x = self.cnn_block2(x)

        # Dropout ONLY here
        x = self.dropout_cnn(x)

        x = x.transpose(1, 2)

        # LSTM
        lstm_out, (h, c) = self.lstm(x)
        h_last = h[-1]

        if self.use_batchnorm:
            h_last = self.bn_lstm(h_last)

        # MLP
        x = self.fc1(h_last)
        if self.use_batchnorm:
            x = self.bn_fc1(x)
        x = self.act(x)
        x = self.fc2(x)

        return x

# %%
def run_full_train(
    X_seq_train, y_train,
    X_seq_dev,  y_dev,
    hidden_size=128,
    num_layers=2,
    dropout=0.2,
    use_batchnorm=True,
    leaky_alpha=0.1,
    learning_rate=1e-3,
    weight_decay=0.0,
    l1_lambda=0.0,
    batch_size=128,
    epochs=20,
    verbose_freq=1,
    cnn_channels=32,
    device=device
):

    # numpy → torch
    X_seq_train_t = torch.from_numpy(X_seq_train).float()
    X_seq_dev_t   = torch.from_numpy(X_seq_dev).float()
    y_train_t     = torch.from_numpy(y_train).float()
    y_dev_t       = torch.from_numpy(y_dev).float()

    # ----------------------------------------------------
    # CREATE MODEL (ONLY CHANGE IS BELOW)
    # ----------------------------------------------------
    model = SimpleRNN(
        n_features=X_seq_train.shape[-1],
        seq_len=X_seq_train.shape[1],
        hidden_size=hidden_size,
        num_layers=num_layers,
        dropout=dropout,
        output_dim=1,
        leaky_alpha=leaky_alpha,
        use_batchnorm=use_batchnorm,
        cnn_channels=cnn_channels           # NEW ARG
    ).to(device)

    optimizer = torch.optim.Adam(
        model.parameters(), lr=learning_rate, weight_decay=weight_decay
    )

    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
        optimizer, T_max=epochs, eta_min=learning_rate * 0.1
    )

    mae_loss = torch.nn.L1Loss()

    print(model)

    train_hist = []
    val_hist   = []
    N = len(X_seq_train)

    # -------------------------------------------------
    # TRAINING LOOP
    # -------------------------------------------------
    for epoch in range(epochs):

        model.train()
        perm = torch.randperm(N)
        train_loss_epoch = 0.
        num_batches = 0

        for i in range(0, N, batch_size):

            idx = perm[i:i+batch_size]
            xb = X_seq_train_t[idx].to(device)
            yb = y_train_t[idx].to(device)

            preds = model(xb)
            loss = mae_loss(preds, yb)

            if l1_lambda > 0:
                l1_penalty = sum(p.abs().sum() for p in model.parameters())
                loss += l1_lambda * l1_penalty

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss_epoch += loss.item()
            num_batches += 1

        train_loss_epoch /= num_batches

        model.eval()
        with torch.no_grad():
            val_loss = 0.
            count = 0
            for i in range(0, len(X_seq_dev_t), batch_size):
                xb = X_seq_dev_t[i:i+batch_size].to(device)
                yb = y_dev_t[i:i+batch_size].to(device)

                preds = model(xb)
                loss = mae_loss(preds, yb)

                val_loss += loss.item() * xb.size(0)
                count += xb.size(0)

            val_loss /= count

        train_hist.append(train_loss_epoch)
        val_hist.append(val_loss)

        scheduler.step()

        if epoch % verbose_freq == 0:
            lr_now = scheduler.get_last_lr()[0]
            print(f"Epoch {epoch+1:03d} | Train MAE: {train_loss_epoch:.4f} | "
                  f"Val MAE: {val_loss:.4f} | LR: {lr_now:.6e}")

    return model, train_hist, val_hist

# %%
# --- Main: load CSV, prepare sliding windows, normalize, quick experiments ---
SEED = 42
seed_everything(SEED)

# %%
# experiment config(s)
all_exp_params = {

    "default": {
        'hidden_size': 128,
        'num_layers': 1,
        'dropout': 0.14165080185330172,
        'use_batchnorm': False,
        'leaky_alpha': 0.08954143004580317,
        'learning_rate': 0.0017301665777591376,
        'weight_decay': 1.1107576638258875e-05,
        'l1_lambda': 1.044917998725486e-05,
        'batch_size': 256,
        'epochs': 40,
        'cnn_channels': 16    # ← NEW
    }
}

results_save_path = "rolling_window_exp_results.pkl"
plot_suffix = "_loss_plot.jpg"
exp_results = {}

for tag, params in all_exp_params.items():
    print("Running experiment:", tag)
    
    model, train_hist, val_hist = run_full_train(
        Xrt_train_norm, y_train_norm,
        Xrt_dev_norm,   y_dev_norm,
        hidden_size=params["hidden_size"],
        num_layers=params["num_layers"],
        dropout=params["dropout"],
        use_batchnorm=params["use_batchnorm"],
        leaky_alpha=params["leaky_alpha"],
        learning_rate=params["learning_rate"],
        weight_decay=params["weight_decay"],
        l1_lambda=params["l1_lambda"],
        batch_size=params["batch_size"],
        epochs=params["epochs"],
        cnn_channels=params["cnn_channels"],    # ← ADDED
        verbose_freq=1
    )

    exp_results[tag] = {
        "train_loss": train_hist,
        "val_loss": val_hist
    }

# save
save_object_to_file(exp_results, results_save_path)

# reload
exp_results = read_object_from_file(results_save_path)

# PLOTS
for tag, r in exp_results.items():
    tr = r["train_loss"]
    va = r["val_loss"]

    plt.clf()
    plt.plot(range(len(tr)), tr, label="Train Loss")
    plt.plot(range(len(va)), va, label="Validation Loss")
    plt.title(f"{tag} Loss vs Epochs")
    plt.xlabel("Epoch")
    plt.ylabel("MAE")
    plt.legend(loc="upper right")
    plt.savefig(tag + plot_suffix)

plt.clf()
plt.show()
# Out:
# Running experiment: default
# SimpleRNN(
#   (cnn_block1): Sequential(
#     (0): Conv1d(10, 16, kernel_size=(5,), stride=(1,), padding=(2,))
#     (1): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (cnn_block2): Sequential(
#     (0): Conv1d(16, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (dropout_cnn): Dropout(p=0.14165080185330173, inplace=False)
#   (lstm): LSTM(16, 128, batch_first=True)
#   (fc1): Linear(in_features=128, out_features=128, bias=True)
#   (act): LeakyReLU(negative_slope=0.08954143004580317)
#   (fc2): Linear(in_features=128, out_features=1, bias=True)
# )
# Epoch 001 | Train MAE: 0.2676 | Val MAE: 0.1480 | LR: 1.727766e-03
# Epoch 002 | Train MAE: 0.1621 | Val MAE: 0.1550 | LR: 1.720581e-03
# Epoch 003 | Train MAE: 0.1421 | Val MAE: 0.1526 | LR: 1.708654e-03
# Epoch 004 | Train MAE: 0.1328 | Val MAE: 0.1324 | LR: 1.692060e-03
# Epoch 005 | Train MAE: 0.1259 | Val MAE: 0.1385 | LR: 1.670901e-03
# Epoch 006 | Train MAE: 0.1211 | Val MAE: 0.1303 | LR: 1.645307e-03
# Epoch 007 | Train MAE: 0.1166 | Val MAE: 0.1225 | LR: 1.615436e-03
# Epoch 008 | Train MAE: 0.1142 | Val MAE: 0.1145 | LR: 1.581472e-03
# Epoch 009 | Train MAE: 0.1106 | Val MAE: 0.1136 | LR: 1.543625e-03
# Epoch 010 | Train MAE: 0.1063 | Val MAE: 0.1074 | LR: 1.502127e-03
# Epoch 011 | Train MAE: 0.1059 | Val MAE: 0.1042 | LR: 1.457236e-03
# Epoch 012 | Train MAE: 0.1042 | Val MAE: 0.1038 | LR: 1.409226e-03
# Epoch 013 | Train MAE: 0.1020 | Val MAE: 0.0972 | LR: 1.358396e-03
# Epoch 014 | Train MAE: 0.1023 | Val MAE: 0.0995 | LR: 1.305057e-03
# Epoch 015 | Train MAE: 0.1006 | Val MAE: 0.0974 | LR: 1.249539e-03
# Epoch 016 | Train MAE: 0.0993 | Val MAE: 0.0991 | LR: 1.192185e-03
# Epoch 017 | Train MAE: 0.0977 | Val MAE: 0.0962 | LR: 1.133346e-03
# Epoch 018 | Train MAE: 0.0976 | Val MAE: 0.1096 | LR: 1.073388e-03
# Epoch 019 | Train MAE: 0.0972 | Val MAE: 0.1101 | LR: 1.012678e-03
# Epoch 020 | Train MAE: 0.0959 | Val MAE: 0.0945 | LR: 9.515916e-04
# Epoch 021 | Train MAE: 0.0956 | Val MAE: 0.1000 | LR: 8.905053e-04
# Epoch 022 | Train MAE: 0.0953 | Val MAE: 0.0995 | LR: 8.297957e-04
# Epoch 023 | Train MAE: 0.0942 | Val MAE: 0.0955 | LR: 7.698369e-04
# Epoch 024 | Train MAE: 0.0930 | Val MAE: 0.0946 | LR: 7.109987e-04
# Epoch 025 | Train MAE: 0.0933 | Val MAE: 0.0934 | LR: 6.536439e-04
# Epoch 026 | Train MAE: 0.0928 | Val MAE: 0.0975 | LR: 5.981260e-04
# Epoch 027 | Train MAE: 0.0920 | Val MAE: 0.1000 | LR: 5.447873e-04
# Epoch 028 | Train MAE: 0.0932 | Val MAE: 0.0917 | LR: 4.939567e-04
# Epoch 029 | Train MAE: 0.0904 | Val MAE: 0.0923 | LR: 4.459476e-04
# Epoch 030 | Train MAE: 0.0906 | Val MAE: 0.0905 | LR: 4.010560e-04
# Epoch 031 | Train MAE: 0.0908 | Val MAE: 0.0908 | LR: 3.595586e-04
# Epoch 032 | Train MAE: 0.0899 | Val MAE: 0.0916 | LR: 3.217112e-04
# Epoch 033 | Train MAE: 0.0897 | Val MAE: 0.0909 | LR: 2.877473e-04
# Epoch 034 | Train MAE: 0.0894 | Val MAE: 0.0950 | LR: 2.578762e-04
# Epoch 035 | Train MAE: 0.0898 | Val MAE: 0.0918 | LR: 2.322821e-04
# Epoch 036 | Train MAE: 0.0893 | Val MAE: 0.0890 | LR: 2.111228e-04
# Epoch 037 | Train MAE: 0.0894 | Val MAE: 0.0898 | LR: 1.945287e-04
# Epoch 038 | Train MAE: 0.0887 | Val MAE: 0.0897 | LR: 1.826022e-04
# Epoch 039 | Train MAE: 0.0882 | Val MAE: 0.0893 | LR: 1.754167e-04
# Epoch 040 | Train MAE: 0.0884 | Val MAE: 0.0891 | LR: 1.730167e-04

# %%
num_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"Trainable parameters: {num_params:,}")
# Out:
# Trainable parameters: 92,993

# %%
def evaluate_model(
    model,
    X_seq_np,
    y_np,
    y_np_1d,
    y_np_7d,
    stats_dict,
    batch_size,
    device="cpu"
):
    """
    Evaluation for MULTI-STEP forecasting (e.g. H=24).
    y_np must be shape (N, H)
    model outputs (N, H)
    """

    # ----------------------
    # Get normalization stats
    # ----------------------
    mean_FR = stats_dict["price_EUR/MWh"]["mean"]
    std_FR  = stats_dict["price_EUR/MWh"]["std"]

    model = model.to(device).eval()

    N = len(X_seq_np)
    preds_list = []

    # ----------------------
    # Predict
    # ----------------------
    with torch.no_grad():
        for i in range(0, N, batch_size):

            xb_seq = torch.from_numpy(X_seq_np[i:i+batch_size]).float().to(device)

            out = model(xb_seq)
            preds_list.append(out.cpu().numpy())

    predictions = np.concatenate(preds_list, axis=0)  # (N, H)

    # ----------------------
    # Denormalize
    # ----------------------
    predictions = predictions * std_FR + mean_FR
    y_np        = y_np        * std_FR + mean_FR

    # ----------------------
    # Metrics (multi-step)
    # ----------------------

    # MAE averaged over all 24 steps
    mae = np.mean(np.abs(predictions - y_np))

    # Median baseline (per horizon)
    median_val = np.median(y_np, axis=0)          # shape (H,)
    mae_median = np.mean(np.abs(median_val - y_np))
    maem = mae / mae_median

    # rMAE using naive (t-24)
    mae_model_1d = mae
    mae_naive_1d = np.mean(np.abs(y_np_1d - y_np))   # y_np_1d is (N,H)
    rMAE_1d = mae_model_1d / mae_naive_1d

    # rMAE using naive (t-168)
    mae_model_7d = mae
    mae_naive_7d = np.mean(np.abs(y_np_7d - y_np))
    rMAE_7d = mae_model_7d / mae_naive_7d



    print(f"MAE: {mae:.4f} | MAEm: {maem:.4f} | rMAE-1d: {rMAE_1d:.4f} | rMAE-7d: {rMAE_7d:.4f}" )

    return {
        "predictions": predictions,
        "MAE": mae,
        "MAEm": maem,
        "rMAE_1d": rMAE_1d,
        "rMAE_7d": rMAE_7d
    }

# %%
print("Evaluating on test set:")
eval_res_test = evaluate_model(model, Xrt_test_norm, y_test_norm, y1d_test, y7d_test, stats_dict, batch_size=params["batch_size"], device=device)
print("Evaluating on the dev set:")
eval_res_dev = evaluate_model(model, Xrt_dev_norm, y_dev_norm, y1d_dev, y7d_dev, stats_dict, batch_size=params["batch_size"], device=device)
print("Evaluating on train set:")
eval_res_train = evaluate_model(model, Xrt_train_norm, y_train_norm, y1d_train, y7d_train, stats_dict, batch_size=params["batch_size"], device=device)
# Out:
# Evaluating on test set:
# MAE: 7.9273 | MAEm: 0.1420 | rMAE-1d: 0.3578 | rMAE-7d: 0.2582
# Evaluating on the dev set:
# MAE: 8.7446 | MAEm: 0.0982 | rMAE-1d: 0.3623 | rMAE-7d: 0.2290
# Evaluating on train set:
# MAE: 7.0908 | MAEm: 0.1039 | rMAE-1d: 0.3186 | rMAE-7d: 0.2288

# %%
#save predictions as .pkl file
preds=eval_res_test["predictions"]
save_object_to_file(preds, "predictions_cnn_rnn.pkl")

# %%
hours_train = np.arange(eval_res_train["predictions"].shape[0]) % 24
hours_dev   = np.arange(eval_res_dev["predictions"].shape[0]) % 24
hours_test  = np.arange(eval_res_test["predictions"].shape[0]) % 24

# %%
def per_hour_metrics(preds, y,y1d,y7d, hours):
    preds = preds.squeeze()
    y = y.squeeze()
    med=np.median(y)
    mae = np.zeros(24)
    maem=np.zeros(24)
    rmae1 = np.zeros(24)
    rmae7 = np.zeros(24)
    for h in range(24):
        mask = (hours == h)
        mae[h] = np.mean(np.abs(preds[mask] - y[mask]))
        maem[h] = mae[h]/np.mean(np.abs(preds[mask] - med))
        rmae1[h] = mae[h]/np.mean(np.abs(preds[mask] - y1d[mask]))
        rmae7[h] = mae[h]/np.mean(np.abs(preds[mask] - y7d[mask]))
    return mae, maem, rmae1, rmae7

# %%
#Per-hour prediction on the train/dev/test
mae_train_hour,maem_train_hour,rmae1_train_hour,rmae7_train_hour = per_hour_metrics(eval_res_train["predictions"], y_train, y1d_train, y7d_train, hours_train)
mae_dev_hour,maem_dev_hour,rmae1_dev_hour,rmae7_dev_hour   = per_hour_metrics(eval_res_dev["predictions"],   y_dev,   y1d_dev,   y7d_dev,   hours_dev)
mae_test_hour,maem_test_hour,rmae1_test_hour,rmae7_test_hour  = per_hour_metrics(eval_res_test["predictions"],  y_test,  y1d_test,  y7d_test,  hours_test)

# %%
hours = np.arange(24)
width = 0.28

fig, axes = plt.subplots(2, 2, figsize=(16, 10))

# -------------------------------------
# 1) MAE per hour
# -------------------------------------
ax = axes[0, 0]
ax.bar(hours - width, mae_train_hour, width, label="Train",color='#1f77b4')
ax.bar(hours,         mae_dev_hour,   width, label="Dev", color='#ff7f0e')
ax.bar(hours + width, mae_test_hour,  width, label="Test", color='#2ca02c')
ax.set_title("MAE per Hour")
ax.set_xlabel("Hour of Day")
ax.set_ylabel("MAE (EUR/MWh)")
ax.set_xticks(hours)
ax.grid(axis='y', linestyle='--', alpha=0.4)

# -------------------------------------
# 2) MAEm per hour
# -------------------------------------
ax = axes[0, 1]
ax.bar(hours - width, maem_train_hour, width, label="Train", color='#1f77b4')
ax.bar(hours,         maem_dev_hour,   width, label="Dev", color='#ff7f0e')
ax.bar(hours + width, maem_test_hour,  width, label="Test", color='#2ca02c')
ax.set_title("MAEm per Hour (vs Median Baseline)")
ax.set_xlabel("Hour of Day")
ax.set_ylabel("MAEm")
ax.set_xticks(hours)
ax.grid(axis='y', linestyle='--', alpha=0.4)

# -------------------------------------
# 3) rMAE 1-day per hour
# -------------------------------------
ax = axes[1, 0]
ax.bar(hours - width, rmae1_train_hour, width, label="Train", color='#1f77b4')
ax.bar(hours,         rmae1_dev_hour,   width, label="Dev", color='#ff7f0e')
ax.bar(hours + width, rmae1_test_hour,  width, label="Test", color='#2ca02c')
ax.set_title("rMAE per Hour (1-day Naive)")
ax.set_xlabel("Hour of Day")
ax.set_ylabel("rMAE₁d")
ax.set_xticks(hours)
ax.grid(axis='y', linestyle='--', alpha=0.4)

# -------------------------------------
# 4) rMAE 7-day per hour
# -------------------------------------
ax = axes[1, 1]
ax.bar(hours - width, rmae7_train_hour, width, label="Train", color='#1f77b4')
ax.bar(hours,         rmae7_dev_hour,   width, label="Dev", color='#ff7f0e')
ax.bar(hours + width, rmae7_test_hour,  width, label="Test", color='#2ca02c')
ax.set_title("rMAE per Hour (7-day Naive)")
ax.set_xlabel("Hour of Day")
ax.set_ylabel("rMAE₇d")
ax.set_xticks(hours)
ax.grid(axis='y', linestyle='--', alpha=0.4)

# -------------------------------------
# Final formatting
# -------------------------------------
handles, labels = axes[0,0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center', ncol=3, fontsize=12)

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
#Plot on the training set
plt.figure(figsize=(12,6))
idx=np.random.randint(0, len(eval_res_train["predictions"])-24)
plt.plot(y_train[idx:idx+24], label="True Prices")
plt.plot(eval_res_train["predictions"][idx:idx+24], label="Predicted Prices")
plt.title("Training Set: True vs Predicted Prices (sample index {})".format(idx))
plt.xlabel("Sample Index")
plt.ylabel("Price (EUR/MWh)")
plt.legend()
plt.show()

# %%
# -----------------------------
# Hyperparameter Tuning (clean)
# -----------------------------

results = {}   # store all results
cnn_values = [16, 32, 64]
dropout_values = [0.1, 0.3, 0.5]

for cnn in cnn_values:
    for d in dropout_values:

        print("="*60)
        print(f"Training with cnn={cnn}  | dropout={d}")
        print("="*60)

        model, train_hist, val_hist = run_full_train(
        Xrt_train_norm, y_train_norm,
        Xrt_dev_norm,   y_dev_norm,
        hidden_size=params["hidden_size"],
        num_layers=params["num_layers"],
        dropout=d,
        use_batchnorm=params["use_batchnorm"],
        leaky_alpha=params["leaky_alpha"],
        learning_rate=params["learning_rate"],
        weight_decay=params["weight_decay"],
        l1_lambda=params["l1_lambda"],
        batch_size=params["batch_size"],
        epochs=params["epochs"],
        cnn_channels=cnn,    # ← ADDED
        verbose_freq=1
    )

        print("Evaluating on dev set...")
        eval_res_dev = evaluate_model(
            model,
            Xrt_dev_norm,
            y_dev_norm,
            y1d_dev,
            y7d_dev,
            stats_dict,
            batch_size=256,
            device=device
        )

        # store clean results
        results[(cnn, d)] = {
            "MAE"   : eval_res_dev["MAE"],
            "MAEm"  : eval_res_dev["MAEm"],
            "rMAE1" : eval_res_dev["rMAE_1d"],
            "rMAE7" : eval_res_dev["rMAE_7d"],
        }

# -----------------------------
# Extract best configurations
# -----------------------------
min_mae   = min(v["MAE"]   for v in results.values())
min_maem  = min(v["MAEm"]  for v in results.values())
min_rmae1 = min(v["rMAE1"] for v in results.values())
min_rmae7 = min(v["rMAE7"] for v in results.values())

best_configs_mae   = [k for k,v in results.items() if v["MAE"]   == min_mae]
best_configs_maem  = [k for k,v in results.items() if v["MAEm"]  == min_maem]
best_configs_rmae1 = [k for k,v in results.items() if v["rMAE1"] == min_rmae1]
best_configs_rmae7 = [k for k,v in results.items() if v["rMAE7"] == min_rmae7]

print("\n=========== BEST CONFIGURATIONS ===========")
print(f"Best MAE ({min_mae:.4f}):            {best_configs_mae}")
print(f"Best MAEm ({min_maem:.4f}):          {best_configs_maem}")
print(f"Best rMAE-1d ({min_rmae1:.4f}):       {best_configs_rmae1}")
print(f"Best rMAE-7d ({min_rmae7:.4f}):       {best_configs_rmae7}")
print("==========================================\n")
# Out:
# ============================================================
# Training with cnn=16  | dropout=0.1
# ============================================================
# SimpleRNN(
#   (cnn_block1): Sequential(
#     (0): Conv1d(10, 16, kernel_size=(5,), stride=(1,), padding=(2,))
#     (1): LeakyReLU(negative_slope=0.08954143004580317)
#     (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (cnn_block2): Sequential(
#     (0): Conv1d(16, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): LeakyReLU(negative_slope=0.08954143004580317)
#     (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (lstm): LSTM(16, 128, batch_first=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (fc1): Linear(in_features=128, out_features=128, bias=True)
#   (act): LeakyReLU(negative_slope=0.08954143004580317)
#   (fc2): Linear(in_features=128, out_features=1, bias=True)
# )
# Epoch 001 | Train MAE: 0.2940 | Val MAE: 0.1841 | LR: 1.727766e-03
# Epoch 002 | Train MAE: 0.1305 | Val MAE: 0.1429 | LR: 1.720581e-03
# Epoch 003 | Train MAE: 0.1109 | Val MAE: 0.1268 | LR: 1.708654e-03
# Epoch 004 | Train MAE: 0.1009 | Val MAE: 0.1177 | LR: 1.692060e-03
# Epoch 005 | Train MAE: 0.0970 | Val MAE: 0.1116 | LR: 1.670901e-03
# Epoch 006 | Train MAE: 0.0939 | Val MAE: 0.1017 | LR: 1.645307e-03
# Epoch 007 | Train MAE: 0.0931 | Val MAE: 0.1029 | LR: 1.615436e-03
# Epoch 008 | Train MAE: 0.0888 | Val MAE: 0.1035 | LR: 1.581472e-03
# Epoch 009 | Train MAE: 0.0882 | Val MAE: 0.0933 | LR: 1.543625e-03
# Epoch 010 | Train MAE: 0.0881 | Val MAE: 0.0989 | LR: 1.502127e-03
# Epoch 011 | Train MAE: 0.0864 | Val MAE: 0.0953 | LR: 1.457236e-03
# Epoch 012 | Train MAE: 0.0855 | Val MAE: 0.1027 | LR: 1.409226e-03
# Epoch 013 | Train MAE: 0.0856 | Val MAE: 0.0976 | LR: 1.358396e-03
# Epoch 014 | Train MAE: 0.0841 | Val MAE: 0.1032 | LR: 1.305057e-03
# Epoch 015 | Train MAE: 0.0833 | Val MAE: 0.1015 | LR: 1.249539e-03
# Epoch 016 | Train MAE: 0.0824 | Val MAE: 0.0942 | LR: 1.192185e-03
# Epoch 017 | Train MAE: 0.0810 | Val MAE: 0.0921 | LR: 1.133346e-03
# Epoch 018 | Train MAE: 0.0815 | Val MAE: 0.0896 | LR: 1.073388e-03
# Epoch 019 | Train MAE: 0.0818 | Val MAE: 0.0905 | LR: 1.012678e-03
# Epoch 020 | Train MAE: 0.0804 | Val MAE: 0.0879 | LR: 9.515916e-04
# Epoch 021 | Train MAE: 0.0801 | Val MAE: 0.0962 | LR: 8.905053e-04
# Epoch 022 | Train MAE: 0.0803 | Val MAE: 0.0948 | LR: 8.297957e-04
# Epoch 023 | Train MAE: 0.0794 | Val MAE: 0.0929 | LR: 7.698369e-04
# Epoch 024 | Train MAE: 0.0792 | Val MAE: 0.0913 | LR: 7.109987e-04
# Epoch 025 | Train MAE: 0.0788 | Val MAE: 0.0894 | LR: 6.536439e-04
# Epoch 026 | Train MAE: 0.0784 | Val MAE: 0.0899 | LR: 5.981260e-04
# Epoch 027 | Train MAE: 0.0778 | Val MAE: 0.0890 | LR: 5.447873e-04
# Epoch 028 | Train MAE: 0.0773 | Val MAE: 0.0882 | LR: 4.939567e-04
# Epoch 029 | Train MAE: 0.0765 | Val MAE: 0.0875 | LR: 4.459476e-04
# Epoch 030 | Train MAE: 0.0770 | Val MAE: 0.0925 | LR: 4.010560e-04
# Epoch 031 | Train MAE: 0.0769 | Val MAE: 0.0872 | LR: 3.595586e-04
# Epoch 032 | Train MAE: 0.0764 | Val MAE: 0.0875 | LR: 3.217112e-04
# Epoch 033 | Train MAE: 0.0761 | Val MAE: 0.0875 | LR: 2.877473e-04
# Epoch 034 | Train MAE: 0.0761 | Val MAE: 0.0866 | LR: 2.578762e-04
# Epoch 035 | Train MAE: 0.0758 | Val MAE: 0.0876 | LR: 2.322821e-04
# Epoch 036 | Train MAE: 0.0756 | Val MAE: 0.0881 | LR: 2.111228e-04
# Epoch 037 | Train MAE: 0.0753 | Val MAE: 0.0872 | LR: 1.945287e-04
# Epoch 038 | Train MAE: 0.0756 | Val MAE: 0.0868 | LR: 1.826022e-04
# Epoch 039 | Train MAE: 0.0751 | Val MAE: 0.0866 | LR: 1.754167e-04
# Epoch 040 | Train MAE: 0.0750 | Val MAE: 0.0859 | LR: 1.730167e-04
# Evaluating on dev set...
# MAE: 8.4287 | MAEm: 0.0946 | rMAE-1d: 0.3492 | rMAE-7d: 0.2208
# ============================================================
# Training with cnn=16  | dropout=0.3
# ============================================================
# SimpleRNN(
#   (cnn_block1): Sequential(
#     (0): Conv1d(10, 16, kernel_size=(5,), stride=(1,), padding=(2,))
#     (1): LeakyReLU(negative_slope=0.08954143004580317)
#     (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (cnn_block2): Sequential(
#     (0): Conv1d(16, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): LeakyReLU(negative_slope=0.08954143004580317)
#     (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (lstm): LSTM(16, 128, batch_first=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (fc1): Linear(in_features=128, out_features=128, bias=True)
#   (act): LeakyReLU(negative_slope=0.08954143004580317)
#   (fc2): Linear(in_features=128, out_features=1, bias=True)
# )
# Epoch 001 | Train MAE: 0.2928 | Val MAE: 0.1879 | LR: 1.727766e-03
# Epoch 002 | Train MAE: 0.1420 | Val MAE: 0.1338 | LR: 1.720581e-03
# Epoch 003 | Train MAE: 0.1238 | Val MAE: 0.1342 | LR: 1.708654e-03
# Epoch 004 | Train MAE: 0.1158 | Val MAE: 0.1209 | LR: 1.692060e-03
# Epoch 005 | Train MAE: 0.1101 | Val MAE: 0.1108 | LR: 1.670901e-03
# Epoch 006 | Train MAE: 0.1076 | Val MAE: 0.1070 | LR: 1.645307e-03
# Epoch 007 | Train MAE: 0.1055 | Val MAE: 0.1066 | LR: 1.615436e-03
# Epoch 008 | Train MAE: 0.1021 | Val MAE: 0.1040 | LR: 1.581472e-03
# Epoch 009 | Train MAE: 0.1010 | Val MAE: 0.1025 | LR: 1.543625e-03
# Epoch 010 | Train MAE: 0.0993 | Val MAE: 0.1019 | LR: 1.502127e-03
# Epoch 011 | Train MAE: 0.0984 | Val MAE: 0.1037 | LR: 1.457236e-03
# Epoch 012 | Train MAE: 0.0985 | Val MAE: 0.0985 | LR: 1.409226e-03
# Epoch 013 | Train MAE: 0.0965 | Val MAE: 0.0958 | LR: 1.358396e-03
# Epoch 014 | Train MAE: 0.0964 | Val MAE: 0.1021 | LR: 1.305057e-03
# Epoch 015 | Train MAE: 0.0952 | Val MAE: 0.0936 | LR: 1.249539e-03
# Epoch 016 | Train MAE: 0.0953 | Val MAE: 0.0983 | LR: 1.192185e-03
# Epoch 017 | Train MAE: 0.0942 | Val MAE: 0.0988 | LR: 1.133346e-03
# Epoch 018 | Train MAE: 0.0943 | Val MAE: 0.0996 | LR: 1.073388e-03
# Epoch 019 | Train MAE: 0.0937 | Val MAE: 0.0979 | LR: 1.012678e-03
# Epoch 020 | Train MAE: 0.0926 | Val MAE: 0.0936 | LR: 9.515916e-04
# Epoch 021 | Train MAE: 0.0920 | Val MAE: 0.0977 | LR: 8.905053e-04
# Epoch 022 | Train MAE: 0.0923 | Val MAE: 0.0947 | LR: 8.297957e-04
# Epoch 023 | Train MAE: 0.0916 | Val MAE: 0.0929 | LR: 7.698369e-04
# Epoch 024 | Train MAE: 0.0906 | Val MAE: 0.0952 | LR: 7.109987e-04
# Epoch 025 | Train MAE: 0.0905 | Val MAE: 0.0971 | LR: 6.536439e-04
# Epoch 026 | Train MAE: 0.0895 | Val MAE: 0.0937 | LR: 5.981260e-04
# Epoch 027 | Train MAE: 0.0901 | Val MAE: 0.1030 | LR: 5.447873e-04
# Epoch 028 | Train MAE: 0.0898 | Val MAE: 0.0928 | LR: 4.939567e-04
# Epoch 029 | Train MAE: 0.0890 | Val MAE: 0.0910 | LR: 4.459476e-04
# Epoch 030 | Train MAE: 0.0888 | Val MAE: 0.0924 | LR: 4.010560e-04
# Epoch 031 | Train MAE: 0.0885 | Val MAE: 0.0950 | LR: 3.595586e-04
# Epoch 032 | Train MAE: 0.0881 | Val MAE: 0.0924 | LR: 3.217112e-04
# Epoch 033 | Train MAE: 0.0881 | Val MAE: 0.0989 | LR: 2.877473e-04
# Epoch 034 | Train MAE: 0.0878 | Val MAE: 0.0884 | LR: 2.578762e-04
# Epoch 035 | Train MAE: 0.0877 | Val MAE: 0.0919 | LR: 2.322821e-04
# Epoch 036 | Train MAE: 0.0868 | Val MAE: 0.0906 | LR: 2.111228e-04
# Epoch 037 | Train MAE: 0.0870 | Val MAE: 0.0896 | LR: 1.945287e-04
# Epoch 038 | Train MAE: 0.0878 | Val MAE: 0.0916 | LR: 1.826022e-04
# Epoch 039 | Train MAE: 0.0870 | Val MAE: 0.0889 | LR: 1.754167e-04
# Epoch 040 | Train MAE: 0.0874 | Val MAE: 0.0883 | LR: 1.730167e-04
# Evaluating on dev set...
# MAE: 8.6618 | MAEm: 0.0972 | rMAE-1d: 0.3589 | rMAE-7d: 0.2269
# ============================================================
# Training with cnn=16  | dropout=0.5
# ============================================================
# SimpleRNN(
#   (cnn_block1): Sequential(
#     (0): Conv1d(10, 16, kernel_size=(5,), stride=(1,), padding=(2,))
#     (1): LeakyReLU(negative_slope=0.08954143004580317)
#     (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (cnn_block2): Sequential(
#     (0): Conv1d(16, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): LeakyReLU(negative_slope=0.08954143004580317)
#     (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (lstm): LSTM(16, 128, batch_first=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc1): Linear(in_features=128, out_features=128, bias=True)
#   (act): LeakyReLU(negative_slope=0.08954143004580317)
#   (fc2): Linear(in_features=128, out_features=1, bias=True)
# )
# Epoch 001 | Train MAE: 0.2749 | Val MAE: 0.1486 | LR: 1.727766e-03
# Epoch 002 | Train MAE: 0.1441 | Val MAE: 0.1306 | LR: 1.720581e-03
# Epoch 003 | Train MAE: 0.1343 | Val MAE: 0.1303 | LR: 1.708654e-03
# Epoch 004 | Train MAE: 0.1257 | Val MAE: 0.1141 | LR: 1.692060e-03
# Epoch 005 | Train MAE: 0.1202 | Val MAE: 0.1159 | LR: 1.670901e-03
# Epoch 006 | Train MAE: 0.1176 | Val MAE: 0.1114 | LR: 1.645307e-03
# Epoch 007 | Train MAE: 0.1151 | Val MAE: 0.1046 | LR: 1.615436e-03
# Epoch 008 | Train MAE: 0.1132 | Val MAE: 0.1079 | LR: 1.581472e-03
# Epoch 009 | Train MAE: 0.1130 | Val MAE: 0.0994 | LR: 1.543625e-03
# Epoch 010 | Train MAE: 0.1101 | Val MAE: 0.0993 | LR: 1.502127e-03
# Epoch 011 | Train MAE: 0.1098 | Val MAE: 0.1015 | LR: 1.457236e-03
# Epoch 012 | Train MAE: 0.1091 | Val MAE: 0.1136 | LR: 1.409226e-03
# Epoch 013 | Train MAE: 0.1087 | Val MAE: 0.1009 | LR: 1.358396e-03
# Epoch 014 | Train MAE: 0.1055 | Val MAE: 0.0965 | LR: 1.305057e-03
# Epoch 015 | Train MAE: 0.1050 | Val MAE: 0.1016 | LR: 1.249539e-03
# Epoch 016 | Train MAE: 0.1038 | Val MAE: 0.1072 | LR: 1.192185e-03
# Epoch 017 | Train MAE: 0.1029 | Val MAE: 0.0949 | LR: 1.133346e-03
# Epoch 018 | Train MAE: 0.1010 | Val MAE: 0.0951 | LR: 1.073388e-03
# Epoch 019 | Train MAE: 0.1005 | Val MAE: 0.0920 | LR: 1.012678e-03
# Epoch 020 | Train MAE: 0.0997 | Val MAE: 0.0904 | LR: 9.515916e-04
# Epoch 021 | Train MAE: 0.1002 | Val MAE: 0.0939 | LR: 8.905053e-04
# Epoch 022 | Train MAE: 0.0991 | Val MAE: 0.0914 | LR: 8.297957e-04
# Epoch 023 | Train MAE: 0.0987 | Val MAE: 0.0969 | LR: 7.698369e-04
# Epoch 024 | Train MAE: 0.0988 | Val MAE: 0.0950 | LR: 7.109987e-04
# Epoch 025 | Train MAE: 0.0981 | Val MAE: 0.0918 | LR: 6.536439e-04
# Epoch 026 | Train MAE: 0.0980 | Val MAE: 0.0928 | LR: 5.981260e-04
# Epoch 027 | Train MAE: 0.0972 | Val MAE: 0.0950 | LR: 5.447873e-04
# Epoch 028 | Train MAE: 0.0961 | Val MAE: 0.0888 | LR: 4.939567e-04
# Epoch 029 | Train MAE: 0.0967 | Val MAE: 0.1000 | LR: 4.459476e-04
# Epoch 030 | Train MAE: 0.0954 | Val MAE: 0.0889 | LR: 4.010560e-04
# Epoch 031 | Train MAE: 0.0961 | Val MAE: 0.0921 | LR: 3.595586e-04
# Epoch 032 | Train MAE: 0.0952 | Val MAE: 0.0938 | LR: 3.217112e-04
# Epoch 033 | Train MAE: 0.0962 | Val MAE: 0.0895 | LR: 2.877473e-04
# Epoch 034 | Train MAE: 0.0950 | Val MAE: 0.0889 | LR: 2.578762e-04
# Epoch 035 | Train MAE: 0.0952 | Val MAE: 0.0882 | LR: 2.322821e-04
# Epoch 036 | Train MAE: 0.0941 | Val MAE: 0.0890 | LR: 2.111228e-04
# Epoch 037 | Train MAE: 0.0944 | Val MAE: 0.0885 | LR: 1.945287e-04
# Epoch 038 | Train MAE: 0.0946 | Val MAE: 0.0934 | LR: 1.826022e-04
# Epoch 039 | Train MAE: 0.0948 | Val MAE: 0.0894 | LR: 1.754167e-04
# Epoch 040 | Train MAE: 0.0949 | Val MAE: 0.0891 | LR: 1.730167e-04
# Evaluating on dev set...
# MAE: 8.7435 | MAEm: 0.0982 | rMAE-1d: 0.3622 | rMAE-7d: 0.2290
# ============================================================
# Training with cnn=32  | dropout=0.1
# ============================================================
# SimpleRNN(
#   (cnn_block1): Sequential(
#     (0): Conv1d(10, 32, kernel_size=(5,), stride=(1,), padding=(2,))
#     (1): LeakyReLU(negative_slope=0.08954143004580317)
#     (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (cnn_block2): Sequential(
#     (0): Conv1d(32, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): LeakyReLU(negative_slope=0.08954143004580317)
#     (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (lstm): LSTM(32, 128, batch_first=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (fc1): Linear(in_features=128, out_features=128, bias=True)
#   (act): LeakyReLU(negative_slope=0.08954143004580317)
#   (fc2): Linear(in_features=128, out_features=1, bias=True)
# )
# Epoch 001 | Train MAE: 0.2472 | Val MAE: 0.1551 | LR: 1.727766e-03
# Epoch 002 | Train MAE: 0.1175 | Val MAE: 0.1228 | LR: 1.720581e-03
# Epoch 003 | Train MAE: 0.1046 | Val MAE: 0.1131 | LR: 1.708654e-03
# Epoch 004 | Train MAE: 0.0983 | Val MAE: 0.1137 | LR: 1.692060e-03
# Epoch 005 | Train MAE: 0.0931 | Val MAE: 0.1106 | LR: 1.670901e-03
# Epoch 006 | Train MAE: 0.0919 | Val MAE: 0.1039 | LR: 1.645307e-03
# Epoch 007 | Train MAE: 0.0889 | Val MAE: 0.0994 | LR: 1.615436e-03
# Epoch 008 | Train MAE: 0.0860 | Val MAE: 0.0987 | LR: 1.581472e-03
# Epoch 009 | Train MAE: 0.0859 | Val MAE: 0.0948 | LR: 1.543625e-03
# Epoch 010 | Train MAE: 0.0842 | Val MAE: 0.1087 | LR: 1.502127e-03
# Epoch 011 | Train MAE: 0.0839 | Val MAE: 0.0983 | LR: 1.457236e-03
# Epoch 012 | Train MAE: 0.0827 | Val MAE: 0.0958 | LR: 1.409226e-03
# Epoch 013 | Train MAE: 0.0843 | Val MAE: 0.0969 | LR: 1.358396e-03
# Epoch 014 | Train MAE: 0.0827 | Val MAE: 0.0901 | LR: 1.305057e-03
# Epoch 015 | Train MAE: 0.0803 | Val MAE: 0.0911 | LR: 1.249539e-03
# Epoch 016 | Train MAE: 0.0798 | Val MAE: 0.0912 | LR: 1.192185e-03
# Epoch 017 | Train MAE: 0.0785 | Val MAE: 0.0926 | LR: 1.133346e-03
# Epoch 018 | Train MAE: 0.0784 | Val MAE: 0.0893 | LR: 1.073388e-03
# Epoch 019 | Train MAE: 0.0775 | Val MAE: 0.0899 | LR: 1.012678e-03
# Epoch 020 | Train MAE: 0.0781 | Val MAE: 0.0935 | LR: 9.515916e-04
# Epoch 021 | Train MAE: 0.0775 | Val MAE: 0.0885 | LR: 8.905053e-04
# Epoch 022 | Train MAE: 0.0765 | Val MAE: 0.0887 | LR: 8.297957e-04
# Epoch 023 | Train MAE: 0.0761 | Val MAE: 0.0887 | LR: 7.698369e-04
# Epoch 024 | Train MAE: 0.0757 | Val MAE: 0.0912 | LR: 7.109987e-04
# Epoch 025 | Train MAE: 0.0755 | Val MAE: 0.0870 | LR: 6.536439e-04
# Epoch 026 | Train MAE: 0.0749 | Val MAE: 0.0914 | LR: 5.981260e-04
# Epoch 027 | Train MAE: 0.0749 | Val MAE: 0.0871 | LR: 5.447873e-04
# Epoch 028 | Train MAE: 0.0742 | Val MAE: 0.0876 | LR: 4.939567e-04
# Epoch 029 | Train MAE: 0.0739 | Val MAE: 0.0878 | LR: 4.459476e-04
# Epoch 030 | Train MAE: 0.0734 | Val MAE: 0.0878 | LR: 4.010560e-04
# Epoch 031 | Train MAE: 0.0735 | Val MAE: 0.0857 | LR: 3.595586e-04
# Epoch 032 | Train MAE: 0.0728 | Val MAE: 0.0859 | LR: 3.217112e-04
# Epoch 033 | Train MAE: 0.0728 | Val MAE: 0.0871 | LR: 2.877473e-04
# Epoch 034 | Train MAE: 0.0722 | Val MAE: 0.0866 | LR: 2.578762e-04
# Epoch 035 | Train MAE: 0.0719 | Val MAE: 0.0856 | LR: 2.322821e-04
# Epoch 036 | Train MAE: 0.0720 | Val MAE: 0.0855 | LR: 2.111228e-04
# Epoch 037 | Train MAE: 0.0720 | Val MAE: 0.0854 | LR: 1.945287e-04
# Epoch 038 | Train MAE: 0.0718 | Val MAE: 0.0856 | LR: 1.826022e-04
# Epoch 039 | Train MAE: 0.0713 | Val MAE: 0.0861 | LR: 1.754167e-04
# Epoch 040 | Train MAE: 0.0714 | Val MAE: 0.0865 | LR: 1.730167e-04
# Evaluating on dev set...
# MAE: 8.4905 | MAEm: 0.0953 | rMAE-1d: 0.3518 | rMAE-7d: 0.2224
# ============================================================
# Training with cnn=32  | dropout=0.3
# ============================================================
# SimpleRNN(
#   (cnn_block1): Sequential(
#     (0): Conv1d(10, 32, kernel_size=(5,), stride=(1,), padding=(2,))
#     (1): LeakyReLU(negative_slope=0.08954143004580317)
#     (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (cnn_block2): Sequential(
#     (0): Conv1d(32, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): LeakyReLU(negative_slope=0.08954143004580317)
#     (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (lstm): LSTM(32, 128, batch_first=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (fc1): Linear(in_features=128, out_features=128, bias=True)
#   (act): LeakyReLU(negative_slope=0.08954143004580317)
#   (fc2): Linear(in_features=128, out_features=1, bias=True)
# )
# Epoch 001 | Train MAE: 0.2448 | Val MAE: 0.1921 | LR: 1.727766e-03
# Epoch 002 | Train MAE: 0.1359 | Val MAE: 0.1211 | LR: 1.720581e-03
# Epoch 003 | Train MAE: 0.1181 | Val MAE: 0.1136 | LR: 1.708654e-03
# Epoch 004 | Train MAE: 0.1097 | Val MAE: 0.1038 | LR: 1.692060e-03
# Epoch 005 | Train MAE: 0.1073 | Val MAE: 0.1088 | LR: 1.670901e-03
# Epoch 006 | Train MAE: 0.1036 | Val MAE: 0.1166 | LR: 1.645307e-03
# Epoch 007 | Train MAE: 0.1013 | Val MAE: 0.1033 | LR: 1.615436e-03
# Epoch 008 | Train MAE: 0.0997 | Val MAE: 0.1107 | LR: 1.581472e-03
# Epoch 009 | Train MAE: 0.0967 | Val MAE: 0.0961 | LR: 1.543625e-03
# Epoch 010 | Train MAE: 0.0955 | Val MAE: 0.1075 | LR: 1.502127e-03
# Epoch 011 | Train MAE: 0.0954 | Val MAE: 0.0967 | LR: 1.457236e-03
# Epoch 012 | Train MAE: 0.0965 | Val MAE: 0.1128 | LR: 1.409226e-03
# Epoch 013 | Train MAE: 0.0944 | Val MAE: 0.1306 | LR: 1.358396e-03
# Epoch 014 | Train MAE: 0.0923 | Val MAE: 0.0928 | LR: 1.305057e-03
# Epoch 015 | Train MAE: 0.0915 | Val MAE: 0.0895 | LR: 1.249539e-03
# Epoch 016 | Train MAE: 0.0906 | Val MAE: 0.0906 | LR: 1.192185e-03
# Epoch 017 | Train MAE: 0.0909 | Val MAE: 0.0931 | LR: 1.133346e-03
# Epoch 018 | Train MAE: 0.0898 | Val MAE: 0.0951 | LR: 1.073388e-03
# Epoch 019 | Train MAE: 0.0892 | Val MAE: 0.0895 | LR: 1.012678e-03
# Epoch 020 | Train MAE: 0.0879 | Val MAE: 0.0904 | LR: 9.515916e-04
# Epoch 021 | Train MAE: 0.0888 | Val MAE: 0.1031 | LR: 8.905053e-04
# Epoch 022 | Train MAE: 0.0875 | Val MAE: 0.0931 | LR: 8.297957e-04
# Epoch 023 | Train MAE: 0.0869 | Val MAE: 0.0903 | LR: 7.698369e-04
# Epoch 024 | Train MAE: 0.0872 | Val MAE: 0.0966 | LR: 7.109987e-04
# Epoch 025 | Train MAE: 0.0858 | Val MAE: 0.0914 | LR: 6.536439e-04
# Epoch 026 | Train MAE: 0.0851 | Val MAE: 0.0937 | LR: 5.981260e-04
# Epoch 027 | Train MAE: 0.0858 | Val MAE: 0.0865 | LR: 5.447873e-04
# Epoch 028 | Train MAE: 0.0840 | Val MAE: 0.0906 | LR: 4.939567e-04
# Epoch 029 | Train MAE: 0.0829 | Val MAE: 0.0855 | LR: 4.459476e-04
# Epoch 030 | Train MAE: 0.0823 | Val MAE: 0.0902 | LR: 4.010560e-04
# Epoch 031 | Train MAE: 0.0819 | Val MAE: 0.0891 | LR: 3.595586e-04
# Epoch 032 | Train MAE: 0.0822 | Val MAE: 0.0878 | LR: 3.217112e-04
# Epoch 033 | Train MAE: 0.0820 | Val MAE: 0.0901 | LR: 2.877473e-04
# Epoch 034 | Train MAE: 0.0813 | Val MAE: 0.0888 | LR: 2.578762e-04
# Epoch 035 | Train MAE: 0.0819 | Val MAE: 0.0851 | LR: 2.322821e-04
# Epoch 036 | Train MAE: 0.0813 | Val MAE: 0.0857 | LR: 2.111228e-04
# Epoch 037 | Train MAE: 0.0808 | Val MAE: 0.0871 | LR: 1.945287e-04
# Epoch 038 | Train MAE: 0.0812 | Val MAE: 0.0854 | LR: 1.826022e-04
# Epoch 039 | Train MAE: 0.0803 | Val MAE: 0.0855 | LR: 1.754167e-04
# Epoch 040 | Train MAE: 0.0804 | Val MAE: 0.0852 | LR: 1.730167e-04
# Evaluating on dev set...
# MAE: 8.3546 | MAEm: 0.0938 | rMAE-1d: 0.3461 | rMAE-7d: 0.2188
# ============================================================
# Training with cnn=32  | dropout=0.5
# ============================================================
# SimpleRNN(
#   (cnn_block1): Sequential(
#     (0): Conv1d(10, 32, kernel_size=(5,), stride=(1,), padding=(2,))
#     (1): LeakyReLU(negative_slope=0.08954143004580317)
#     (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (cnn_block2): Sequential(
#     (0): Conv1d(32, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): LeakyReLU(negative_slope=0.08954143004580317)
#     (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (lstm): LSTM(32, 128, batch_first=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc1): Linear(in_features=128, out_features=128, bias=True)
#   (act): LeakyReLU(negative_slope=0.08954143004580317)
#   (fc2): Linear(in_features=128, out_features=1, bias=True)
# )
# Epoch 001 | Train MAE: 0.2498 | Val MAE: 0.1459 | LR: 1.727766e-03
# Epoch 002 | Train MAE: 0.1417 | Val MAE: 0.1207 | LR: 1.720581e-03
# Epoch 003 | Train MAE: 0.1301 | Val MAE: 0.1165 | LR: 1.708654e-03
# Epoch 004 | Train MAE: 0.1222 | Val MAE: 0.1210 | LR: 1.692060e-03
# Epoch 005 | Train MAE: 0.1181 | Val MAE: 0.1104 | LR: 1.670901e-03
# Epoch 006 | Train MAE: 0.1153 | Val MAE: 0.1022 | LR: 1.645307e-03
# Epoch 007 | Train MAE: 0.1128 | Val MAE: 0.1050 | LR: 1.615436e-03
# Epoch 008 | Train MAE: 0.1128 | Val MAE: 0.1067 | LR: 1.581472e-03
# Epoch 009 | Train MAE: 0.1121 | Val MAE: 0.1081 | LR: 1.543625e-03
# Epoch 010 | Train MAE: 0.1104 | Val MAE: 0.1050 | LR: 1.502127e-03
# Epoch 011 | Train MAE: 0.1072 | Val MAE: 0.0976 | LR: 1.457236e-03
# Epoch 012 | Train MAE: 0.1053 | Val MAE: 0.1084 | LR: 1.409226e-03
# Epoch 013 | Train MAE: 0.1045 | Val MAE: 0.0941 | LR: 1.358396e-03
# Epoch 014 | Train MAE: 0.1041 | Val MAE: 0.1142 | LR: 1.305057e-03
# Epoch 015 | Train MAE: 0.1032 | Val MAE: 0.1055 | LR: 1.249539e-03
# Epoch 016 | Train MAE: 0.1022 | Val MAE: 0.0954 | LR: 1.192185e-03
# Epoch 017 | Train MAE: 0.1004 | Val MAE: 0.0998 | LR: 1.133346e-03
# Epoch 018 | Train MAE: 0.0996 | Val MAE: 0.0988 | LR: 1.073388e-03
# Epoch 019 | Train MAE: 0.0981 | Val MAE: 0.0968 | LR: 1.012678e-03
# Epoch 020 | Train MAE: 0.0978 | Val MAE: 0.0974 | LR: 9.515916e-04
# Epoch 021 | Train MAE: 0.0982 | Val MAE: 0.0907 | LR: 8.905053e-04
# Epoch 022 | Train MAE: 0.0965 | Val MAE: 0.0946 | LR: 8.297957e-04
# Epoch 023 | Train MAE: 0.0957 | Val MAE: 0.0969 | LR: 7.698369e-04
# Epoch 024 | Train MAE: 0.0954 | Val MAE: 0.0902 | LR: 7.109987e-04
# Epoch 025 | Train MAE: 0.0950 | Val MAE: 0.0904 | LR: 6.536439e-04
# Epoch 026 | Train MAE: 0.0948 | Val MAE: 0.0866 | LR: 5.981260e-04
# Epoch 027 | Train MAE: 0.0943 | Val MAE: 0.0888 | LR: 5.447873e-04
# Epoch 028 | Train MAE: 0.0948 | Val MAE: 0.0888 | LR: 4.939567e-04
# Epoch 029 | Train MAE: 0.0940 | Val MAE: 0.0880 | LR: 4.459476e-04
# Epoch 030 | Train MAE: 0.0934 | Val MAE: 0.0875 | LR: 4.010560e-04
# Epoch 031 | Train MAE: 0.0924 | Val MAE: 0.0927 | LR: 3.595586e-04
# Epoch 032 | Train MAE: 0.0923 | Val MAE: 0.0859 | LR: 3.217112e-04
# Epoch 033 | Train MAE: 0.0924 | Val MAE: 0.0879 | LR: 2.877473e-04
# Epoch 034 | Train MAE: 0.0915 | Val MAE: 0.0863 | LR: 2.578762e-04
# Epoch 035 | Train MAE: 0.0918 | Val MAE: 0.0848 | LR: 2.322821e-04
# Epoch 036 | Train MAE: 0.0911 | Val MAE: 0.0907 | LR: 2.111228e-04
# Epoch 037 | Train MAE: 0.0918 | Val MAE: 0.0862 | LR: 1.945287e-04
# Epoch 038 | Train MAE: 0.0910 | Val MAE: 0.0890 | LR: 1.826022e-04
# Epoch 039 | Train MAE: 0.0911 | Val MAE: 0.0871 | LR: 1.754167e-04
# Epoch 040 | Train MAE: 0.0903 | Val MAE: 0.0880 | LR: 1.730167e-04
# Evaluating on dev set...
# MAE: 8.6324 | MAEm: 0.0969 | rMAE-1d: 0.3576 | rMAE-7d: 0.2261
# ============================================================
# Training with cnn=64  | dropout=0.1
# ============================================================
# SimpleRNN(
#   (cnn_block1): Sequential(
#     (0): Conv1d(10, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#     (1): LeakyReLU(negative_slope=0.08954143004580317)
#     (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (cnn_block2): Sequential(
#     (0): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): LeakyReLU(negative_slope=0.08954143004580317)
#     (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (lstm): LSTM(64, 128, batch_first=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (fc1): Linear(in_features=128, out_features=128, bias=True)
#   (act): LeakyReLU(negative_slope=0.08954143004580317)
#   (fc2): Linear(in_features=128, out_features=1, bias=True)
# )
# Epoch 001 | Train MAE: 0.2100 | Val MAE: 0.1426 | LR: 1.727766e-03
# Epoch 002 | Train MAE: 0.1154 | Val MAE: 0.1141 | LR: 1.720581e-03
# Epoch 003 | Train MAE: 0.1029 | Val MAE: 0.1147 | LR: 1.708654e-03
# Epoch 004 | Train MAE: 0.0965 | Val MAE: 0.1252 | LR: 1.692060e-03
# Epoch 005 | Train MAE: 0.0937 | Val MAE: 0.0988 | LR: 1.670901e-03
# Epoch 006 | Train MAE: 0.0911 | Val MAE: 0.1061 | LR: 1.645307e-03
# Epoch 007 | Train MAE: 0.0897 | Val MAE: 0.1040 | LR: 1.615436e-03
# Epoch 008 | Train MAE: 0.0877 | Val MAE: 0.0966 | LR: 1.581472e-03
# Epoch 009 | Train MAE: 0.0850 | Val MAE: 0.1051 | LR: 1.543625e-03
# Epoch 010 | Train MAE: 0.0870 | Val MAE: 0.0954 | LR: 1.502127e-03
# Epoch 011 | Train MAE: 0.0834 | Val MAE: 0.1041 | LR: 1.457236e-03
# Epoch 012 | Train MAE: 0.0833 | Val MAE: 0.1157 | LR: 1.409226e-03
# Epoch 013 | Train MAE: 0.0828 | Val MAE: 0.0898 | LR: 1.358396e-03
# Epoch 014 | Train MAE: 0.0805 | Val MAE: 0.0940 | LR: 1.305057e-03
# Epoch 015 | Train MAE: 0.0792 | Val MAE: 0.0972 | LR: 1.249539e-03
# Epoch 016 | Train MAE: 0.0792 | Val MAE: 0.0916 | LR: 1.192185e-03
# Epoch 017 | Train MAE: 0.0778 | Val MAE: 0.0919 | LR: 1.133346e-03
# Epoch 018 | Train MAE: 0.0773 | Val MAE: 0.0932 | LR: 1.073388e-03
# Epoch 019 | Train MAE: 0.0771 | Val MAE: 0.0891 | LR: 1.012678e-03
# Epoch 020 | Train MAE: 0.0756 | Val MAE: 0.0933 | LR: 9.515916e-04
# Epoch 021 | Train MAE: 0.0763 | Val MAE: 0.0893 | LR: 8.905053e-04
# Epoch 022 | Train MAE: 0.0750 | Val MAE: 0.0890 | LR: 8.297957e-04
# Epoch 023 | Train MAE: 0.0762 | Val MAE: 0.0860 | LR: 7.698369e-04
# Epoch 024 | Train MAE: 0.0733 | Val MAE: 0.0858 | LR: 7.109987e-04
# Epoch 025 | Train MAE: 0.0735 | Val MAE: 0.0870 | LR: 6.536439e-04
# Epoch 026 | Train MAE: 0.0732 | Val MAE: 0.0864 | LR: 5.981260e-04
# Epoch 027 | Train MAE: 0.0731 | Val MAE: 0.0859 | LR: 5.447873e-04
# Epoch 028 | Train MAE: 0.0717 | Val MAE: 0.0874 | LR: 4.939567e-04
# Epoch 029 | Train MAE: 0.0712 | Val MAE: 0.0855 | LR: 4.459476e-04
# Epoch 030 | Train MAE: 0.0709 | Val MAE: 0.0898 | LR: 4.010560e-04
# Epoch 031 | Train MAE: 0.0709 | Val MAE: 0.0895 | LR: 3.595586e-04
# Epoch 032 | Train MAE: 0.0698 | Val MAE: 0.0881 | LR: 3.217112e-04
# Epoch 033 | Train MAE: 0.0698 | Val MAE: 0.0865 | LR: 2.877473e-04
# Epoch 034 | Train MAE: 0.0703 | Val MAE: 0.0855 | LR: 2.578762e-04
# Epoch 035 | Train MAE: 0.0690 | Val MAE: 0.0868 | LR: 2.322821e-04
# Epoch 036 | Train MAE: 0.0687 | Val MAE: 0.0842 | LR: 2.111228e-04
# Epoch 037 | Train MAE: 0.0687 | Val MAE: 0.0873 | LR: 1.945287e-04
# Epoch 038 | Train MAE: 0.0690 | Val MAE: 0.0854 | LR: 1.826022e-04
# Epoch 039 | Train MAE: 0.0680 | Val MAE: 0.0840 | LR: 1.754167e-04
# Epoch 040 | Train MAE: 0.0681 | Val MAE: 0.0847 | LR: 1.730167e-04
# Evaluating on dev set...
# MAE: 8.3137 | MAEm: 0.0933 | rMAE-1d: 0.3444 | rMAE-7d: 0.2178
# ============================================================
# Training with cnn=64  | dropout=0.3
# ============================================================
# SimpleRNN(
#   (cnn_block1): Sequential(
#     (0): Conv1d(10, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#     (1): LeakyReLU(negative_slope=0.08954143004580317)
#     (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (cnn_block2): Sequential(
#     (0): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): LeakyReLU(negative_slope=0.08954143004580317)
#     (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (lstm): LSTM(64, 128, batch_first=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (fc1): Linear(in_features=128, out_features=128, bias=True)
#   (act): LeakyReLU(negative_slope=0.08954143004580317)
#   (fc2): Linear(in_features=128, out_features=1, bias=True)
# )
# Epoch 001 | Train MAE: 0.2283 | Val MAE: 0.1421 | LR: 1.727766e-03
# Epoch 002 | Train MAE: 0.1256 | Val MAE: 0.1185 | LR: 1.720581e-03
# Epoch 003 | Train MAE: 0.1123 | Val MAE: 0.1101 | LR: 1.708654e-03
# Epoch 004 | Train MAE: 0.1070 | Val MAE: 0.1085 | LR: 1.692060e-03
# Epoch 005 | Train MAE: 0.1057 | Val MAE: 0.1192 | LR: 1.670901e-03
# Epoch 006 | Train MAE: 0.1024 | Val MAE: 0.1245 | LR: 1.645307e-03
# Epoch 007 | Train MAE: 0.0998 | Val MAE: 0.0974 | LR: 1.615436e-03
# Epoch 008 | Train MAE: 0.0962 | Val MAE: 0.1043 | LR: 1.581472e-03
# Epoch 009 | Train MAE: 0.0949 | Val MAE: 0.0946 | LR: 1.543625e-03
# Epoch 010 | Train MAE: 0.0942 | Val MAE: 0.1049 | LR: 1.502127e-03
# Epoch 011 | Train MAE: 0.0952 | Val MAE: 0.0970 | LR: 1.457236e-03
# Epoch 012 | Train MAE: 0.0928 | Val MAE: 0.0926 | LR: 1.409226e-03
# Epoch 013 | Train MAE: 0.0922 | Val MAE: 0.0872 | LR: 1.358396e-03
# Epoch 014 | Train MAE: 0.0915 | Val MAE: 0.0961 | LR: 1.305057e-03
# Epoch 015 | Train MAE: 0.0906 | Val MAE: 0.0907 | LR: 1.249539e-03
# Epoch 016 | Train MAE: 0.0895 | Val MAE: 0.0905 | LR: 1.192185e-03
# Epoch 017 | Train MAE: 0.0883 | Val MAE: 0.0906 | LR: 1.133346e-03
# Epoch 018 | Train MAE: 0.0875 | Val MAE: 0.0898 | LR: 1.073388e-03
# Epoch 019 | Train MAE: 0.0874 | Val MAE: 0.0916 | LR: 1.012678e-03
# Epoch 020 | Train MAE: 0.0866 | Val MAE: 0.0895 | LR: 9.515916e-04
# Epoch 021 | Train MAE: 0.0858 | Val MAE: 0.0889 | LR: 8.905053e-04
# Epoch 022 | Train MAE: 0.0853 | Val MAE: 0.0856 | LR: 8.297957e-04
# Epoch 023 | Train MAE: 0.0855 | Val MAE: 0.0926 | LR: 7.698369e-04
# Epoch 024 | Train MAE: 0.0838 | Val MAE: 0.0914 | LR: 7.109987e-04
# Epoch 025 | Train MAE: 0.0837 | Val MAE: 0.0866 | LR: 6.536439e-04
# Epoch 026 | Train MAE: 0.0834 | Val MAE: 0.0946 | LR: 5.981260e-04
# Epoch 027 | Train MAE: 0.0826 | Val MAE: 0.0878 | LR: 5.447873e-04
# Epoch 028 | Train MAE: 0.0817 | Val MAE: 0.0851 | LR: 4.939567e-04
# Epoch 029 | Train MAE: 0.0820 | Val MAE: 0.0877 | LR: 4.459476e-04
# Epoch 030 | Train MAE: 0.0807 | Val MAE: 0.0908 | LR: 4.010560e-04
# Epoch 031 | Train MAE: 0.0808 | Val MAE: 0.0848 | LR: 3.595586e-04
# Epoch 032 | Train MAE: 0.0799 | Val MAE: 0.0869 | LR: 3.217112e-04
# Epoch 033 | Train MAE: 0.0801 | Val MAE: 0.0862 | LR: 2.877473e-04
# Epoch 034 | Train MAE: 0.0791 | Val MAE: 0.0847 | LR: 2.578762e-04
# Epoch 035 | Train MAE: 0.0793 | Val MAE: 0.0870 | LR: 2.322821e-04
# Epoch 036 | Train MAE: 0.0789 | Val MAE: 0.0850 | LR: 2.111228e-04
# Epoch 037 | Train MAE: 0.0790 | Val MAE: 0.0863 | LR: 1.945287e-04
# Epoch 038 | Train MAE: 0.0782 | Val MAE: 0.0855 | LR: 1.826022e-04
# Epoch 039 | Train MAE: 0.0780 | Val MAE: 0.0849 | LR: 1.754167e-04
# Epoch 040 | Train MAE: 0.0783 | Val MAE: 0.0846 | LR: 1.730167e-04
# Evaluating on dev set...
# MAE: 8.2987 | MAEm: 0.0932 | rMAE-1d: 0.3438 | rMAE-7d: 0.2174
# ============================================================
# Training with cnn=64  | dropout=0.5
# ============================================================
# SimpleRNN(
#   (cnn_block1): Sequential(
#     (0): Conv1d(10, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#     (1): LeakyReLU(negative_slope=0.08954143004580317)
#     (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (cnn_block2): Sequential(
#     (0): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): LeakyReLU(negative_slope=0.08954143004580317)
#     (2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (lstm): LSTM(64, 128, batch_first=True)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc1): Linear(in_features=128, out_features=128, bias=True)
#   (act): LeakyReLU(negative_slope=0.08954143004580317)
#   (fc2): Linear(in_features=128, out_features=1, bias=True)
# )
# Epoch 001 | Train MAE: 0.2238 | Val MAE: 0.1348 | LR: 1.727766e-03
# Epoch 002 | Train MAE: 0.1337 | Val MAE: 0.1212 | LR: 1.720581e-03
# Epoch 003 | Train MAE: 0.1251 | Val MAE: 0.1127 | LR: 1.708654e-03
# Epoch 004 | Train MAE: 0.1194 | Val MAE: 0.1055 | LR: 1.692060e-03
# Epoch 005 | Train MAE: 0.1156 | Val MAE: 0.1006 | LR: 1.670901e-03
# Epoch 006 | Train MAE: 0.1142 | Val MAE: 0.1062 | LR: 1.645307e-03
# Epoch 007 | Train MAE: 0.1098 | Val MAE: 0.1005 | LR: 1.615436e-03
# Epoch 008 | Train MAE: 0.1088 | Val MAE: 0.1055 | LR: 1.581472e-03
# Epoch 009 | Train MAE: 0.1063 | Val MAE: 0.1141 | LR: 1.543625e-03
# Epoch 010 | Train MAE: 0.1047 | Val MAE: 0.0984 | LR: 1.502127e-03
# Epoch 011 | Train MAE: 0.1023 | Val MAE: 0.0993 | LR: 1.457236e-03
# Epoch 012 | Train MAE: 0.1021 | Val MAE: 0.0977 | LR: 1.409226e-03
# Epoch 013 | Train MAE: 0.1012 | Val MAE: 0.0908 | LR: 1.358396e-03
# Epoch 014 | Train MAE: 0.0992 | Val MAE: 0.1004 | LR: 1.305057e-03
# Epoch 015 | Train MAE: 0.1004 | Val MAE: 0.1015 | LR: 1.249539e-03
# Epoch 016 | Train MAE: 0.0982 | Val MAE: 0.0974 | LR: 1.192185e-03
# Epoch 017 | Train MAE: 0.0972 | Val MAE: 0.0926 | LR: 1.133346e-03
# Epoch 018 | Train MAE: 0.0972 | Val MAE: 0.0933 | LR: 1.073388e-03
# Epoch 019 | Train MAE: 0.0963 | Val MAE: 0.0908 | LR: 1.012678e-03
# Epoch 020 | Train MAE: 0.0956 | Val MAE: 0.0896 | LR: 9.515916e-04
# Epoch 021 | Train MAE: 0.0961 | Val MAE: 0.1026 | LR: 8.905053e-04
# Epoch 022 | Train MAE: 0.0961 | Val MAE: 0.0941 | LR: 8.297957e-04
# Epoch 023 | Train MAE: 0.0942 | Val MAE: 0.0874 | LR: 7.698369e-04
# Epoch 024 | Train MAE: 0.0930 | Val MAE: 0.0907 | LR: 7.109987e-04
# Epoch 025 | Train MAE: 0.0924 | Val MAE: 0.0950 | LR: 6.536439e-04
# Epoch 026 | Train MAE: 0.0929 | Val MAE: 0.0903 | LR: 5.981260e-04
# Epoch 027 | Train MAE: 0.0916 | Val MAE: 0.0867 | LR: 5.447873e-04
# Epoch 028 | Train MAE: 0.0908 | Val MAE: 0.0912 | LR: 4.939567e-04
# Epoch 029 | Train MAE: 0.0908 | Val MAE: 0.0932 | LR: 4.459476e-04
# Epoch 030 | Train MAE: 0.0909 | Val MAE: 0.0895 | LR: 4.010560e-04
# Epoch 031 | Train MAE: 0.0905 | Val MAE: 0.0886 | LR: 3.595586e-04
# Epoch 032 | Train MAE: 0.0912 | Val MAE: 0.0889 | LR: 3.217112e-04
# Epoch 033 | Train MAE: 0.0894 | Val MAE: 0.0899 | LR: 2.877473e-04
# Epoch 034 | Train MAE: 0.0897 | Val MAE: 0.0891 | LR: 2.578762e-04
# Epoch 035 | Train MAE: 0.0894 | Val MAE: 0.0861 | LR: 2.322821e-04
# Epoch 036 | Train MAE: 0.0896 | Val MAE: 0.0865 | LR: 2.111228e-04
# Epoch 037 | Train MAE: 0.0894 | Val MAE: 0.0948 | LR: 1.945287e-04
# Epoch 038 | Train MAE: 0.0885 | Val MAE: 0.0865 | LR: 1.826022e-04
# Epoch 039 | Train MAE: 0.0883 | Val MAE: 0.0865 | LR: 1.754167e-04
# Epoch 040 | Train MAE: 0.0886 | Val MAE: 0.0870 | LR: 1.730167e-04
# Evaluating on dev set...
# MAE: 8.5406 | MAEm: 0.0959 | rMAE-1d: 0.3538 | rMAE-7d: 0.2237
#
# =========== BEST CONFIGURATIONS ===========
# Best MAE (8.2987):            [(64, 0.3)]
# Best MAEm (0.0932):          [(64, 0.3)]
# Best rMAE-1d (0.3438):       [(64, 0.3)]
# Best rMAE-7d (0.2174):       [(64, 0.3)]
# ==========================================

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# ----------------------------------------------------
# 1. Extract axes: learning rates and lambdas
# ----------------------------------------------------
cnn = sorted({cnn for (cnn, _) in results.keys()})
dropouts = sorted({d for (_, d) in results.keys()})

metric_keys = ["MAE", "MAEm", "rMAE1", "rMAE7"]

# ----------------------------------------------------
# 2. Allocate grid for metrics and cell-text
# ----------------------------------------------------
grid = {mk: np.full((len(cnn), len(dropouts)), np.nan, dtype=float)
        for mk in metric_keys}

cell_text = [["" for _ in dropouts] for _ in cnn]

# ----------------------------------------------------
# 3. Fill matrices
# ----------------------------------------------------
for (cnn_val, dropout_val), ev in results.items():
    i = cnn.index(cnn_val)
    j = dropouts.index(dropout_val)

    for mk in metric_keys:
        grid[mk][i, j] = ev[mk]

    cell_text[i][j] = "\n".join(f"{mk}: {ev[mk]:.4f}" for mk in metric_keys)

# ----------------------------------------------------
# 4. Compute minima
# ----------------------------------------------------
min_positions = {}
for mk in metric_keys:
    mat = grid[mk]
    if np.isnan(mat).all():
        min_positions[mk] = []
        continue
    min_val = np.nanmin(mat)
    rows, cols = np.where(np.isclose(mat, min_val, atol=1e-12))
    min_positions[mk] = list(zip(rows, cols))

# ----------------------------------------------------
# 5. Plot
# ----------------------------------------------------
fig, ax = plt.subplots(figsize=(16, 6 + 0.6 * len(cnn)))

ax.set_xlim(-0.5, len(dropouts) - 0.5)
ax.set_ylim(len(cnn) - 0.5, -0.5)

ax.set_xticks(range(len(dropouts)))
ax.set_xticklabels([f"{d:.2f}" for d in dropouts], fontsize=14)

ax.set_yticks(range(len(cnn)))
ax.set_yticklabels([f"{c}" for c in cnn], fontsize=14)
ax.set_xlabel("Dropout Rate", fontsize=16)
ax.set_ylabel("CNN Channels", fontsize=16)

# grid lines
for x in range(len(dropouts) + 1):
    ax.axvline(x - 0.5, color="lightgray", linewidth=0.8)
for y in range(len(cnn) + 1):
    ax.axhline(y - 0.5, color="lightgray", linewidth=0.8)

# colors
colors = ["red", "blue", "green", "purple"]
metric_colors = {metric_keys[i]: colors[i] for i in range(len(metric_keys))}
legend_patches = [patches.Patch(color=metric_colors[mk], label=mk)
                  for mk in metric_keys]

# annotation offsets
y_offsets = [-0.35, -0.12, 0.12, 0.35]

# ----------------------------------------------------
# 6. Annotate cells
# ----------------------------------------------------
for i in range(len(cnn)):
    for j in range(len(dropouts)):
        lines = cell_text[i][j].split("\n")
        for k, mk in enumerate(metric_keys):
            color = metric_colors[mk] if (i, j) in min_positions[mk] else "black"
            ax.text(j, i + y_offsets[k],
                    lines[k],
                    ha="center", va="center",
                    fontsize=13, color=color)

ax.legend(handles=legend_patches, bbox_to_anchor=(1.02, 1),
          loc="upper left")

plt.tight_layout()
plt.show()

# %%
def objective(trial):

    # --- Hyperparameters to tune ---

    dropout       = trial.suggest_float("dropout", 0.0, 0.5)
    cnn_channels  = trial.suggest_categorical("cnn_channels", [16, 32])


    # --- Train ---
    model, train_hist, val_hist = run_full_train(
        Xrt_train_norm, y_train_norm,
        Xrt_dev_norm,   y_dev_norm,
        hidden_size=params["hidden_size"],
        num_layers=params["num_layers"],
        dropout=dropout,
        use_batchnorm=params["use_batchnorm"],
        leaky_alpha=params["leaky_alpha"],
        learning_rate=params["learning_rate"],
        weight_decay=params["weight_decay"],
        l1_lambda=params["l1_lambda"],
        batch_size=params["batch_size"],
        epochs=params["epochs"],
        verbose_freq=10,
        cnn_channels=cnn_channels,
        device=device
    )

    # --- Evaluate on dev set ---
    metrics = evaluate_model(
        model,
        Xrt_dev_norm,
        y_dev_norm,
        y1d_dev,         # your baseline arrays
        y7d_dev,
        stats_dict,      # contains mean/std for denormalization
        batch_size=params["batch_size"],
        device=device
    )

    mae     = metrics["MAE"]
    maem    = metrics["MAEm"]
    r1      = metrics["rMAE_1d"]
    r7      = metrics["rMAE_7d"]

    return mae, maem, r1, r7


# --- Run the multi-objective study ---
study = optuna.create_study(
    directions=["minimize", "minimize", "minimize", "minimize"],
    study_name="FR_LMP_LSTM_TUNING"
)

study.optimize(objective, n_trials=20)

best_trials = study.best_trials
print(f"Found {len(best_trials)} Pareto-optimal trials.\n")

for t in best_trials:
    print("Values:", t.values)
    print("Params:", t.params)
    print("-" * 60)
# Out:
# [I 2025-12-04 00:20:49,588] A new study created in memory with name: FR_LMP_LSTM_TUNING
# SimpleRNN(
#   (cnn_block1): Sequential(
#     (0): Conv1d(10, 16, kernel_size=(5,), stride=(1,), padding=(2,))
#     (1): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (cnn_block2): Sequential(
#     (0): Conv1d(16, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (dropout_cnn): Dropout(p=0.3909782634126938, inplace=False)
#   (lstm): LSTM(16, 128, batch_first=True)
#   (fc1): Linear(in_features=128, out_features=128, bias=True)
#   (act): LeakyReLU(negative_slope=0.08954143004580317)
#   (fc2): Linear(in_features=128, out_features=1, bias=True)
# )
# Epoch 001 | Train MAE: 0.2800 | Val MAE: 0.1834 | LR: 1.729100e-03
# Epoch 011 | Train MAE: 0.1171 | Val MAE: 0.2099 | LR: 1.604560e-03
# Epoch 021 | Train MAE: 0.1052 | Val MAE: 0.2792 | LR: 1.305057e-03
# Epoch 031 | Train MAE: 0.0971 | Val MAE: 0.2846 | LR: 9.108442e-04
# Epoch 041 | Train MAE: 0.0918 | Val MAE: 0.2709 | LR: 5.275493e-04
# Epoch 051 | Train MAE: 0.0886 | Val MAE: 0.2712 | LR: 2.578762e-04
# [I 2025-12-04 00:21:41,750] Trial 0 finished with values: [28.601462609045033, 0.3210959335269275, 1.1849641502851966, 0.749137598466328] and parameters: {'dropout': 0.3909782634126938, 'cnn_channels': 16}.
# MAE: 28.6015 | MAEm: 0.3211 | rMAE-1d: 1.1850 | rMAE-7d: 0.7491
# SimpleRNN(
#   (cnn_block1): Sequential(
#     (0): Conv1d(10, 32, kernel_size=(5,), stride=(1,), padding=(2,))
#     (1): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (cnn_block2): Sequential(
#     (0): Conv1d(32, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (dropout_cnn): Dropout(p=0.20921983018274776, inplace=False)
#   (lstm): LSTM(32, 128, batch_first=True)
#   (fc1): Linear(in_features=128, out_features=128, bias=True)
#   (act): LeakyReLU(negative_slope=0.08954143004580317)
#   (fc2): Linear(in_features=128, out_features=1, bias=True)
# )
# Epoch 001 | Train MAE: 0.2559 | Val MAE: 0.1887 | LR: 1.729100e-03
# Epoch 011 | Train MAE: 0.1030 | Val MAE: 0.1011 | LR: 1.604560e-03
# Epoch 021 | Train MAE: 0.0923 | Val MAE: 0.0923 | LR: 1.305057e-03
# Epoch 031 | Train MAE: 0.0875 | Val MAE: 0.0899 | LR: 9.108442e-04
# Epoch 041 | Train MAE: 0.0839 | Val MAE: 0.0879 | LR: 5.275493e-04
# Epoch 051 | Train MAE: 0.0820 | Val MAE: 0.0912 | LR: 2.578762e-04
# [I 2025-12-04 00:22:45,039] Trial 1 finished with values: [8.541041015928274, 0.0958864788066457, 0.3538569879566163, 0.2237093620887575] and parameters: {'dropout': 0.20921983018274776, 'cnn_channels': 32}.
# MAE: 8.5410 | MAEm: 0.0959 | rMAE-1d: 0.3539 | rMAE-7d: 0.2237
# SimpleRNN(
#   (cnn_block1): Sequential(
#     (0): Conv1d(10, 16, kernel_size=(5,), stride=(1,), padding=(2,))
#     (1): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (cnn_block2): Sequential(
#     (0): Conv1d(16, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (dropout_cnn): Dropout(p=0.037992672796756444, inplace=False)
#   (lstm): LSTM(16, 128, batch_first=True)
#   (fc1): Linear(in_features=128, out_features=128, bias=True)
#   (act): LeakyReLU(negative_slope=0.08954143004580317)
#   (fc2): Linear(in_features=128, out_features=1, bias=True)
# )
# Epoch 001 | Train MAE: 0.2587 | Val MAE: 0.1608 | LR: 1.729100e-03
# Epoch 011 | Train MAE: 0.0978 | Val MAE: 0.0997 | LR: 1.604560e-03
# Epoch 021 | Train MAE: 0.0871 | Val MAE: 0.0920 | LR: 1.305057e-03
# Epoch 031 | Train MAE: 0.0823 | Val MAE: 0.0953 | LR: 9.108442e-04
# Epoch 041 | Train MAE: 0.0797 | Val MAE: 0.0869 | LR: 5.275493e-04
# Epoch 051 | Train MAE: 0.0778 | Val MAE: 0.0868 | LR: 2.578762e-04
# [I 2025-12-04 00:23:52,348] Trial 2 finished with values: [8.42439435002958, 0.09457693843133289, 0.3490242939356981, 0.22065411962249226] and parameters: {'dropout': 0.037992672796756444, 'cnn_channels': 16}.
# MAE: 8.4244 | MAEm: 0.0946 | rMAE-1d: 0.3490 | rMAE-7d: 0.2207
# SimpleRNN(
#   (cnn_block1): Sequential(
#     (0): Conv1d(10, 16, kernel_size=(5,), stride=(1,), padding=(2,))
#     (1): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (cnn_block2): Sequential(
#     (0): Conv1d(16, 16, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (dropout_cnn): Dropout(p=0.48153732805720534, inplace=False)
#   (lstm): LSTM(16, 128, batch_first=True)
#   (fc1): Linear(in_features=128, out_features=128, bias=True)
#   (act): LeakyReLU(negative_slope=0.08954143004580317)
#   (fc2): Linear(in_features=128, out_features=1, bias=True)
# )
# Epoch 001 | Train MAE: 0.2928 | Val MAE: 0.1812 | LR: 1.729100e-03
# Epoch 011 | Train MAE: 0.1199 | Val MAE: 0.2760 | LR: 1.604560e-03
# Epoch 021 | Train MAE: 0.1034 | Val MAE: 0.4102 | LR: 1.305057e-03
# Epoch 031 | Train MAE: 0.0949 | Val MAE: 0.4565 | LR: 9.108442e-04
# Epoch 041 | Train MAE: 0.0897 | Val MAE: 0.4661 | LR: 5.275493e-04
# Epoch 051 | Train MAE: 0.0871 | Val MAE: 0.4883 | LR: 2.578762e-04
# [W 2025-12-04 00:24:51,679] Trial 3 failed with parameters: {'dropout': 0.48153732805720534, 'cnn_channels': 16} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/opt/pytorch/lib/python3.12/site-packages/optuna/study/_optimize.py", line 201, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipykernel_3989/3598080869.py", line 10, in objective
#     model, train_hist, val_hist = run_full_train(
#                                   ^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_3989/1041837259.py", line 99, in run_full_train
#     val_loss += loss.item() * xb.size(0)
#                 ^^^^^^^^^^^
# KeyboardInterrupt
# [W 2025-12-04 00:24:51,680] Trial 3 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 54
#      48 # --- Run the multi-objective study ---
#      49 study = optuna.create_study(
#      50     directions=["minimize", "minimize", "minimize", "minimize"],
#      51     study_name="FR_LMP_LSTM_TUNING"
#      52 )
# ---> 54 study.optimize(objective, n_trials=20)
#      56 best_trials = study.best_trials
#      57 print(f"Found {len(best_trials)} Pareto-optimal trials.\n")
#
# File /opt/pytorch/lib/python3.12/site-packages/optuna/study/study.py:490, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     388 def optimize(
#     389     self,
#     390     func: ObjectiveFuncType,
#    (...)    397     show_progress_bar: bool = False,
#     398 ) -> None:
#     399     """Optimize an objective function.
#     400
#     401     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)    488             If nested invocation of this method occurs.
#     489     """
# --> 490     _optimize(
#     491         study=self,
#     492         func=func,
#     493         n_trials=n_trials,
#     494         timeout=timeout,
#     495         n_jobs=n_jobs,
#     496         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     497         callbacks=callbacks,
#     498         gc_after_trial=gc_after_trial,
#     499         show_progress_bar=show_progress_bar,
#     500     )
#
# File /opt/pytorch/lib/python3.12/site-packages/optuna/study/_optimize.py:63, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      61 try:
#      62     if n_jobs == 1:
# ---> 63         _optimize_sequential(
#      64             study,
#      65             func,
#      66             n_trials,
#      67             timeout,
#      68             catch,
#      69             callbacks,
#      70             gc_after_trial,
#      71             reseed_sampler_rng=False,
#      72             time_start=None,
#      73             progress_bar=progress_bar,
#      74         )
#      75     else:
#      76         if n_jobs == -1:
#
# File /opt/pytorch/lib/python3.12/site-packages/optuna/study/_optimize.py:160, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157         break
#     159 try:
# --> 160     frozen_trial_id = _run_trial(study, func, catch)
#     161 finally:
#     162     # The following line mitigates memory problems that can be occurred in some
#     163     # environments (e.g., services that use computing containers such as GitHub Actions).
#     164     # Please refer to the following PR for further details:
#     165     # https://github.com/optuna/optuna/pull/325.
#     166     if gc_after_trial:
#
# File /opt/pytorch/lib/python3.12/site-packages/optuna/study/_optimize.py:258, in _run_trial(study, func, catch)
#     251         assert False, "Should not reach."
#     253 if (
#     254     updated_state == TrialState.FAIL
#     255     and func_err is not None
#     256     and not isinstance(func_err, catch)
#     257 ):
# --> 258     raise func_err
#     259 return trial._trial_id
#
# File /opt/pytorch/lib/python3.12/site-packages/optuna/study/_optimize.py:201, in _run_trial(study, func, catch)
#     199 with get_heartbeat_thread(trial._trial_id, study._storage):
#     200     try:
# --> 201         value_or_values = func(trial)
#     202     except exceptions.TrialPruned as e:
#     203         # TODO(mamu): Handle multi-objective cases.
#     204         state = TrialState.PRUNED
#
# Cell In[25], line 10, in objective(trial)
#       6 cnn_channels  = trial.suggest_categorical("cnn_channels", [16, 32])
#       9 # --- Train ---
# ---> 10 model, train_hist, val_hist = run_full_train(
#      11     Xrt_train_norm, y_train_norm,
#      12     Xrt_dev_norm,   y_dev_norm,
#      13     hidden_size=params["hidden_size"],
#      14     num_layers=params["num_layers"],
#      15     dropout=dropout,
#      16     use_batchnorm=params["use_batchnorm"],
#      17     leaky_alpha=params["leaky_alpha"],
#      18     learning_rate=params["learning_rate"],
#      19     weight_decay=params["weight_decay"],
#      20     l1_lambda=params["l1_lambda"],
#      21     batch_size=params["batch_size"],
#      22     epochs=params["epochs"],
#      23     verbose_freq=10,
#      24     cnn_channels=cnn_channels,
#      25     device=device
#      26 )
#      28 # --- Evaluate on dev set ---
#      29 metrics = evaluate_model(
#      30     model,
#      31     Xrt_dev_norm,
#    (...)     37     device=device
#      38 )
#
# Cell In[16], line 99, in run_full_train(X_seq_train, y_train, X_seq_dev, y_dev, hidden_size, num_layers, dropout, use_batchnorm, leaky_alpha, learning_rate, weight_decay, l1_lambda, batch_size, epochs, verbose_freq, cnn_channels, device)
#      96     preds = model(xb)
#      97     loss = mae_loss(preds, yb)
# ---> 99     val_loss += loss.item() * xb.size(0)
#     100     count += xb.size(0)
#     102 val_loss /= count
#
# KeyboardInterrupt:
